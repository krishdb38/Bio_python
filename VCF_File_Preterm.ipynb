# %%
import pandas as pd
import numpy as np

# %%
columns = ["CHROM", "POS", "ID", "REF" , "ALT", "QUAL", "FILTER", "INFO", "FORMAT", "DEFAULT"]

# %%
df = pd.read_csv("../datas_not_to_upload/873.PASS.vcf", comment= "#",
                 escapechar= "\\", sep="\t",engine="c",low_memory= True)

# %%
df.columns = columns

# %%
df.head()
# Out:
#   CHROM    POS ID  REF ALT  QUAL FILTER                               INFO  \
# 0  chr1  13116  .    T   G   123   PASS               SNVSB=-5.3;SNVHPOL=3
# 1  chr1  13118  .    A   G   126   PASS               SNVSB=-5.3;SNVHPOL=4
# 2  chr1  13656  .  CAG   C   199   PASS  CIGAR=1M2D;RU=AG;REFREP=1;IDREP=0
# 3  chr1  14699  .    C   G    46   PASS               SNVSB=-8.3;SNVHPOL=2
# 4  chr1  14907  .    A   G   129   PASS              SNVSB=-14.7;SNVHPOL=2
#
#                 FORMAT                 DEFAULT
# 0  GT:GQ:GQX:DP:DPF:AD  0/1:156:123:39:2:20,19
# 1  GT:GQ:GQX:DP:DPF:AD  0/1:159:126:39:2:20,19
# 2     GT:GQ:GQX:DPI:AD     0/1:239:199:34:25,6
# 3  GT:GQ:GQX:DP:DPF:AD     0/1:79:46:24:0:19,5
# 4  GT:GQ:GQX:DP:DPF:AD  0/1:162:129:66:9:43,23

# %%
#df.drop("ID", axis=1, inplace=True) # Remove the Column ID from Axis
df.drop("FILTER", axis = 1, inplace = True)

# %%
df.head()
# Out:
#   CHROM    POS ID  REF ALT  QUAL                               INFO  \
# 0  chr1  13116  .    T   G   123               SNVSB=-5.3;SNVHPOL=3
# 1  chr1  13118  .    A   G   126               SNVSB=-5.3;SNVHPOL=4
# 2  chr1  13656  .  CAG   C   199  CIGAR=1M2D;RU=AG;REFREP=1;IDREP=0
# 3  chr1  14699  .    C   G    46               SNVSB=-8.3;SNVHPOL=2
# 4  chr1  14907  .    A   G   129              SNVSB=-14.7;SNVHPOL=2
#
#                 FORMAT                 DEFAULT
# 0  GT:GQ:GQX:DP:DPF:AD  0/1:156:123:39:2:20,19
# 1  GT:GQ:GQX:DP:DPF:AD  0/1:159:126:39:2:20,19
# 2     GT:GQ:GQX:DPI:AD     0/1:239:199:34:25,6
# 3  GT:GQ:GQX:DP:DPF:AD     0/1:79:46:24:0:19,5
# 4  GT:GQ:GQX:DP:DPF:AD  0/1:162:129:66:9:43,23
