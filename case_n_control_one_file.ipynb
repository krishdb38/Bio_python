# %%
import numpy as np
import pandas as pd

# %%
#df1 = pd.read_csv("../case_con_mer.csv",low_memory=False)
df1 = pd.read_csv("../case_snp.csv")
df2 = pd.read_csv("../control_snp.csv")

# %%
df1[df1["POS"]==47080679]
# Out:
#         #CHROM       POS                     ID REF GEN_873_case.csv  \
# 3328694   chr1  47080679  rs386429394;rs6671527   G              A/A
#
#         GEN_875_case.csv GEN_880_case.csv GEN_910_case.csv GEN_1489_case.csv  \
# 3328694              NaN              A/A              G/A               A/A
#
#         GEN_1584_case.csv GEN_1009_case.csv GEN_989_case.csv  \
# 3328694               A/A               A/A              A/A
#
#         GEN_1119_case.csv GEN_1282_case.csv
# 3328694               A/A               G/A

# %%
df2.tail()
# Out:
#         #CHROM        POS           ID REF GEN_1134_control.csv  \
# 9258966   chr1  249239950            .   T                  NaN
# 9258967   chr1  249240099            .   T                  NaN
# 9258968   chr1  249240217            .   G                 G/GT
# 9258969   chr1  249240248            .   T                  NaN
# 9258970   chr1  249240255  rs372794742  AG                  NaN
#
#         GEN_1293_control.csv GEN_1389_control.csv GEN_1428_control.csv  \
# 9258966                  NaN                  NaN                  NaN
# 9258967                  NaN                  NaN                  NaN
# 9258968                  NaN                  NaN                  NaN
# 9258969                  NaN                  NaN                  NaN
# 9258970                  NaN                  NaN                  NaN
#
#         GEN_1477_control.csv GEN_1481_control.csv GEN_1557_control.csv  \
# 9258966                  NaN                  NaN                  NaN
# 9258967                  NaN                  NaN                  NaN
# 9258968                  NaN                  NaN                  NaN
# 9258969                  NaN                  NaN                  NaN
# 9258970                  NaN                  NaN                  NaN
#
#         GEN_1591_control.csv GEN_1093_control.csv GEN_1316_control.csv
# 9258966                T/TTA                  NaN                  NaN
# 9258967                  NaN                  NaN                 T/TA
# 9258968                 G/GT                  NaN               G/GGTT
# 9258969                  NaN                  NaN                 T/TC
# 9258970                 AG/A                  NaN                  NaN

# %%
df1 = df1.sort_values(by=["POS","ID"])

# %%
df1.shape
# Out:
# (11176568, 24)

# %%
df1 = df1.reset_index(drop=True)

# %%
df1.head()
# Out:
#   #CHROM  POS ID REF GEN_873_case.csv GEN_875_case.csv GEN_880_case.csv  \
# 0   chrM  146  .   T              NaN              NaN              NaN
# 1   chrM  150  .   T              C/C              C/C              C/C
# 2   chrM  152  .   T              NaN              NaN              NaN
# 3  chr17  169  .   C              NaN              NaN              NaN
# 4   chrM  183  .   A              NaN              NaN              NaN
#
#   GEN_910_case.csv GEN_1489_case.csv GEN_1584_case.csv  ...  \
# 0              NaN               NaN               NaN  ...
# 1              NaN               NaN               NaN  ...
# 2              NaN               NaN               NaN  ...
# 3              NaN               NaN               NaN  ...
# 4              NaN               NaN               NaN  ...
#
#   GEN_1134_control.csv GEN_1293_control.csv GEN_1389_control.csv  \
# 0                  NaN                  C/C                  NaN
# 1                  C/C                  C/C                  C/C
# 2                  NaN                  NaN                  C/C
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#   GEN_1428_control.csv GEN_1477_control.csv GEN_1481_control.csv  \
# 0                  NaN                  NaN                  NaN
# 1                  C/C                  C/C                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#   GEN_1557_control.csv GEN_1591_control.csv GEN_1093_control.csv  \
# 0                  NaN                  NaN                  NaN
# 1                  C/C                  NaN                  NaN
# 2                  C/C                  NaN                  NaN
# 3                  NaN                  NaN                  C/G
# 4                  NaN                  NaN                  NaN
#
#   GEN_1316_control.csv
# 0                  NaN
# 1                  NaN
# 2                  C/C
# 3                  NaN
# 4                  G/G
#
# [5 rows x 24 columns]

# %%
col = ['CHROM', 'POS', 'ID', 'REF', '1c', '2c',
       '3c', '4c', '5c',
       '6c', '7c', '8c',
       '9c', '10c', '1cn',
       '2cn', '3cn', '4cn',
       '5cn', '6cn', '7cn',
       '8cn', '9cn', '10cn']

# %%
df1.columns= col

# %%
#df1.to_csv("../case_con_mer.csv",index=False , encoding="utf-8")

# %%
df1 = pd.read_csv("case_con_mer.csv")
