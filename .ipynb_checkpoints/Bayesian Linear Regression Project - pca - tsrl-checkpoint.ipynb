# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction:-Bayesian-Linear-Regression-Project" data-toc-modified-id="Introduction:-Bayesian-Linear-Regression-Project-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction: Bayesian Linear Regression Project</a></span><ul class="toc-item"><li><span><a href="#Dataset" data-toc-modified-id="Dataset-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Dataset</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Read-in-Data-and-Examine" data-toc-modified-id="Read-in-Data-and-Examine-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Read in Data and Examine</a></span></li></ul></li><li><span><a href="#Select-6-Most-Correlated-Variables-with-Final-Score" data-toc-modified-id="Select-6-Most-Correlated-Variables-with-Final-Score-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Select 6 Most Correlated Variables with Final Score</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Rename-Variables" data-toc-modified-id="Rename-Variables-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span>Rename Variables</a></span></li></ul></li><li><span><a href="#Selected-Variables-Distribution-by-Relation-to-Median" data-toc-modified-id="Selected-Variables-Distribution-by-Relation-to-Median-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Selected Variables Distribution by Relation to Median</a></span></li></ul></li><li><span><a href="#Metrics" data-toc-modified-id="Metrics-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Metrics</a></span><ul class="toc-item"><li><span><a href="#Naive-Baseline" data-toc-modified-id="Naive-Baseline-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Naive Baseline</a></span></li></ul></li><li><span><a href="#Standard-Machine-Learning-Models" data-toc-modified-id="Standard-Machine-Learning-Models-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Standard Machine Learning Models</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Visual-Comparison-of-Models" data-toc-modified-id="Visual-Comparison-of-Models-3.2.0.1"><span class="toc-item-num">3.2.0.1&nbsp;&nbsp;</span>Visual Comparison of Models</a></span></li></ul></li></ul></li><li><span><a href="#Formula-from-Ordinary-Least-Squares-Linear-Regression" data-toc-modified-id="Formula-from-Ordinary-Least-Squares-Linear-Regression-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Formula from Ordinary Least Squares Linear Regression</a></span></li></ul></li><li><span><a href="#Implementing-Bayesian-Linear-Regression" data-toc-modified-id="Implementing-Bayesian-Linear-Regression-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Implementing Bayesian Linear Regression</a></span><ul class="toc-item"><li><span><a href="#Create-Model-in-PyMC3-and-Sample-from-Posterior" data-toc-modified-id="Create-Model-in-PyMC3-and-Sample-from-Posterior-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Create Model in PyMC3 and Sample from Posterior</a></span></li></ul></li><li><span><a href="#Examine-Bayesian-Linear-Regression-Results" data-toc-modified-id="Examine-Bayesian-Linear-Regression-Results-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Examine Bayesian Linear Regression Results</a></span><ul class="toc-item"><li><span><a href="#Traceplot-of-All-Samples" data-toc-modified-id="Traceplot-of-All-Samples-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Traceplot of All Samples</a></span><ul class="toc-item"><li><span><a href="#Linear-Formula-from-Bayesian-Inference-using-Mean-of-Parameters" data-toc-modified-id="Linear-Formula-from-Bayesian-Inference-using-Mean-of-Parameters-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Linear Formula from Bayesian Inference using Mean of Parameters</a></span></li></ul></li><li><span><a href="#Evaluate-Bayesian-Model-Using-Mean-of-Model-Parameters" data-toc-modified-id="Evaluate-Bayesian-Model-Using-Mean-of-Model-Parameters-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Evaluate Bayesian Model Using Mean of Model Parameters</a></span></li></ul></li><li><span><a href="#Make-Predictions-from-Model" data-toc-modified-id="Make-Predictions-from-Model-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Make Predictions from Model</a></span><ul class="toc-item"><li><span><a href="#Test-Observations" data-toc-modified-id="Test-Observations-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Test Observations</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Predictions-for-New-Observation" data-toc-modified-id="Predictions-for-New-Observation-6.1.0.1"><span class="toc-item-num">6.1.0.1&nbsp;&nbsp;</span>Predictions for New Observation</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Model-Variable-Effects" data-toc-modified-id="Model-Variable-Effects-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Model Variable Effects</a></span></li><li><span><a href="#Different-Likelihood-Prior-Distribution" data-toc-modified-id="Different-Likelihood-Prior-Distribution-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Different Likelihood Prior Distribution</a></span><ul class="toc-item"><li><span><a href="#Build-Model-and-Perform-Inference" data-toc-modified-id="Build-Model-and-Perform-Inference-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Build Model and Perform Inference</a></span></li><li><span><a href="#Test-the-Model" data-toc-modified-id="Test-the-Model-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Test the Model</a></span></li><li><span><a href="#New-Observation-Predictions" data-toc-modified-id="New-Observation-Predictions-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>New Observation Predictions</a></span></li></ul></li><li><span><a href="#Conclusions" data-toc-modified-id="Conclusions-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Conclusions</a></span></li></ul></div>

# %% [markdown]
# # Introduction: Bayesian Linear Regression Project
#
# In this notebook, we will implement a complete machine learning project, focusing on Bayesian Inference methods, in particular, Bayesian Linear Regression. We will go through the entire machine learning process, cleaning the data, exploring it to find trends, establishing a baseline model, evaluating several machine learning approaches for comparisons, implementing Bayesian Linear Regression, interpreting the results, and presenting the results. Let's get started!
#
# ## Dataset
#
# We are using data on student grades collected from a Portuguese secondary (high) school. This data is from the [UCI machine learning repository](https://archive.ics.uci.edu/ml/datasets/student+performance#), a great collection of datasets for model testing. The data includes academic and personal characteristics of the students as well as final grades. The objective is to predict the final grade from the student information which makes this a __supervised, regression task__. We have a set of training data with known labels, and we want the model to learn a mapping from the features (explanatory variables) to the target (the label) in this case the final grade. It is a regression task because the final grade is a continuous value.

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np
np.random.seed(42)

 
# Matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib
matplotlib.rcParams['font.size'] = 16
matplotlib.rcParams['figure.figsize'] = (9, 9)

import seaborn as sns

from IPython.core.pylabtools import figsize

# Scipy helper functions
from scipy.stats import percentileofscore
from scipy import stats
from scipy.stats.stats import pearsonr

# %%
# Standard ML Models for comparison
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

# Splitting data into training/testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# Distributions
import scipy

# %%
# PyMC3 for Bayesian Inference
import pymc3 as pm
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Users\krish\anaconda3\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# ## Read in Data and Examine

# %%
# Read in class scores
df5 = pd.read_csv('data/bayesian_real/srlbininfo_10000.txt', sep = '\s+', nrows=1000)

# Filter out grades that were 0
#df = df[~df['G3'].isin([0, 1])]
df3 = df5['B1']
#df = df.rename(columns={'G3': 'Grade'})

print(df3)
# Out:
# 0      19.052706
# 1      17.772070
# 2      16.200000
# 3      14.987733
# 4      17.656184
#          ...
# 995     6.077366
# 996    19.420398
# 997     5.532859
# 998     7.040892
# 999     6.642502
# Name: B1, Length: 1000, dtype: float64

# %%
finalDf = pd.read_csv('data/bayesian_real/pca_tsrl/pca_rl_test800.csv', sep = ',')

df9 = finalDf
df = df9

# %%
df
# Out:
#            V_1        V_2        V_3       V_4       V_5       V_6       V_7  \
# 0   -29.755846  -4.344965   1.838167 -3.613447  2.845390  1.312527 -1.200487
# 1   -33.016124  -3.225344  -0.617832 -4.409754  3.478638  0.687405 -2.848905
# 2    -2.325064  -7.209644  -2.915636 -3.089195  2.253496  1.735562 -1.399487
# 3    -7.814232 -17.393018   6.341665 -2.483148  0.432226 -0.029369 -0.682491
# 4   -19.627242  -7.920193   4.828792 -3.153532  1.940464  3.395753 -3.056204
# ..         ...        ...        ...       ...       ...       ...       ...
# 995  19.575176  12.487815  -5.701305 -2.943760 -3.118138 -5.726753 -1.728097
# 996  23.488576   6.186641  -5.113504  5.226377  2.715380 -2.729268 -2.866346
# 997  10.997336   4.314853   1.613112 -4.714961  5.654931  1.693006  4.175219
# 998  11.564482   7.585577   4.412210 -4.214182 -0.916224 -2.431753 -0.808023
# 999  70.471458  -3.890595 -10.041311  4.016932  1.255709 -5.223285  2.333407
#
#           V_8       V_9      V_10  ...     V_792     V_793     V_794  \
# 0   -2.087992  0.392146  0.952966  ... -0.341337 -2.176826  0.938889
# 1   -1.837565  1.101369  0.735564  ... -1.565403  0.247161  0.704135
# 2   -1.453227  0.463520 -1.027945  ... -0.025244  2.918058 -0.278964
# 3    1.600894 -0.040180 -0.703356  ...  0.974663  0.104055  0.501767
# 4    1.086710 -1.395406 -3.179018  ...  0.730102  0.100756  2.015673
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  1.279790  2.255117  8.046295  ... -0.300705  0.267732  0.200092
# 996  0.494243  0.755563  0.963847  ... -0.825373  0.457722 -1.944246
# 997  1.059749 -0.697580 -1.276400  ...  0.764714  1.372234 -0.643720
# 998 -2.292451  0.357803  0.567732  ... -1.039449 -1.068292 -0.569667
# 999 -2.616040  1.091217  1.711283  ... -0.395331 -1.275512  0.548604
#
#         V_795     V_796     V_797     V_798     V_799     V_800         B1
# 0    0.268988 -0.811019 -0.262389 -1.163278 -1.249249 -1.002068  19.052706
# 1   -0.548151 -1.545684 -0.556006 -1.206661  0.543523 -0.603268  17.772070
# 2    0.969215  0.037208  0.667494 -1.118774  0.419586  0.558008  16.200000
# 3   -1.629781 -2.084475  0.494898 -0.321671  0.697453 -0.297740  14.987733
# 4   -0.516188 -0.053523  1.304784 -0.770541  0.731129  0.212227  17.656184
# ..        ...       ...       ...       ...       ...       ...        ...
# 995  0.128433  0.053296  1.205316  0.744258  0.714938  0.865530   6.077366
# 996 -0.443301  1.030228 -0.635370 -0.082369  0.984214  0.209724  19.420398
# 997 -0.407431  0.835191  1.795968  1.359043  0.922191  0.622395   5.532859
# 998 -1.248599  0.370728 -1.361547  1.288287  0.312819  1.715355   7.040892
# 999  0.379123  0.007857 -0.733930  0.016070 -0.255314  0.600012   6.642502
#
# [1000 rows x 801 columns]

# %% [markdown]
# # Select 6 Most Correlated Variables with Final Score

# %%
# Takes in a dataframe, finds the most correlated variables with the
# grade and returns training and testing datasets
def format_data(df):
    # Targets are final grade of student
    #df_x = df
    
    # Drop the school and the grades from features
    #df = df.drop(columns=['school', 'G1', 'G2', 'percentile'])
    
    # One-Hot Encoding of Categorical Variables
    df_y = df['B1']

    # Find correlations with the Grade
    #most_correlated = df_y.corr().abs()['B1'].sort_values(ascending=False)
    
    # Maintain the top 6 most correlation features with Grade
    #ost_correlated = most_correlated[:8]
    #df = pd.concat([df2, df3], axis=1)
    
  #  df = df.loc[:, most_correlated.index]
   # df = df.drop(columns = 'higher_no')
    
    # Split into training/testing sets with 25% split
    X_train, X_test, y_train, y_test = train_test_split(df, df_y,
                                                        test_size = 0.25,
                                                        random_state=42)
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = format_data(df)
X_train.head()
# Out:
#            V_1        V_2       V_3       V_4       V_5       V_6       V_7  \
# 82  -37.656657   0.813122  0.078257 -0.190456 -0.649145  0.230829  0.300561
# 991  74.956676  -7.598335 -2.868160  0.470730 -1.563229  1.363610 -1.842435
# 789   9.258307  12.323899  2.679987 -7.097378  3.793356 -5.028804 -0.181041
# 894  -0.376519  16.854372  1.199644  1.585636 -5.584093  5.478283 -0.557676
# 398  -6.858960  -4.207609 -2.785431  0.292426 -1.808812 -1.748866 -1.313337
#
#           V_8       V_9      V_10  ...     V_792     V_793     V_794  \
# 82  -0.738313  0.341207 -0.358029  ... -0.772667 -0.283585  0.405055
# 991  0.227660  0.842484 -0.254570  ... -1.408423 -0.779825 -1.695116
# 789 -1.268647 -1.974467  3.892336  ...  0.269356 -0.616298  0.302966
# 894 -0.283455 -1.216108 -3.910552  ...  0.159506 -0.097960 -0.480761
# 398  1.061112 -0.758927  1.142068  ...  0.117288  1.957967  0.023818
#
#         V_795     V_796     V_797     V_798     V_799     V_800         B1
# 82   2.169412 -1.331407 -0.217850  0.453267 -2.651282  0.000448  10.201364
# 991  1.849223  0.561348  1.314294  0.687140  0.780081  0.158184  11.980224
# 789 -0.225021 -0.466914 -0.724807 -0.516026 -0.838902  0.174803  12.550562
# 894 -0.338025 -1.008908  0.108976 -0.093271 -0.069817  0.842426   8.257585
# 398 -0.062676 -0.451076 -0.091520 -0.200741  0.039032 -0.207157   9.850674
#
# [5 rows x 801 columns]

# %% [markdown]
# #### Rename Variables

# %%
X_test.head()
# Out:
#            V_1        V_2       V_3       V_4       V_5       V_6       V_7  \
# 521  16.103523 -18.012638  1.774476  0.231863 -1.202637  1.687424 -1.171133
# 737  56.159618  -3.486274 -5.174511  0.325033 -1.189229 -1.151010  0.013529
# 740  37.026199   0.143746 -4.144289 -1.368615  1.362892 -0.858430 -2.688411
# 660  67.783585  -5.306079 -7.665347  5.109947  2.457454 -4.222229  1.309557
# 411 -17.415921  -4.695930  0.369895  4.387471  0.961504 -0.134458 -2.255964
#
#           V_8       V_9      V_10  ...     V_792     V_793     V_794  \
# 521  0.845608 -1.038570 -1.230034  ... -0.220823 -0.973630 -0.003501
# 737  0.461268  0.957132  0.988602  ...  0.961881 -0.963697 -1.015092
# 740 -0.131948  1.917812 -0.509617  ...  0.415907 -0.867920  0.197054
# 660  2.635709 -1.743365  2.626536  ...  0.691680 -1.111830 -0.331353
# 411  1.925419  0.279058  0.138326  ...  0.003301  0.404231 -0.181661
#
#         V_795     V_796     V_797     V_798     V_799     V_800         B1
# 521 -0.054700 -1.528170 -0.462113 -0.051705 -0.456523  0.997542  12.456493
# 737 -0.053711  1.182800 -0.278514  0.278125  0.607490 -0.081726   8.103241
# 740 -0.836328  1.025197  1.333099 -0.146685  0.997710 -0.004084  11.900554
# 660 -0.674694 -0.609308 -0.346780 -0.754269 -0.667639 -0.240466   5.037638
# 411 -0.765042 -1.290083  1.672818 -0.928347 -0.077783 -1.378769  10.286819
#
# [5 rows x 801 columns]

# %%
y_train.head()
# Out:
# 82     10.201364
# 991    11.980224
# 789    12.550562
# 894     8.257585
# 398     9.850674
# Name: B1, dtype: float64

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (750, 801)
# (250, 801)

# %% [markdown]
# ### Selected Variables Distribution by Relation to Median

# %% [markdown]
# ## Metrics
#
# For this regression task, we will use two standard metrics:
#
# * Mean Absolute Error (MAE): Average of the absolute value of the difference between predictions and the true values
# * Root Mean Squared Error (RMSE): The square root of the average of the squared differences between the predictions and the true values.
#
# The mean absolute error is more interpretable, but the root mean squared error penalizes larger errors more heavily. Either one may be appropriate depending on the situation.
# [Here is a discussion](https://medium.com/human-in-a-machine-world/mae-and-rmse-which-metric-is-better-e60ac3bde13d).

# %%
# Calculate mae and rmse
def evaluate_predictions(predictions, true):
    mae = np.mean(abs(predictions - true))
    rmse = np.sqrt(np.mean((predictions - true) ** 2))
    
    return mae, rmse

# %% [markdown]
# ### Naive Baseline
#
# For a regression task, a simple naive baseline is to guess the median value on the training set for all testing cases. If our machine learning model cannot better this simple baseline, then perhaps we should try a different approach!

# %%
# Naive baseline is the median
median_pred = X_train['B1'].median()
median_preds = [median_pred for _ in range(len(X_test))]
true = X_test['B1']

# %%
# Display the naive baseline metrics
mb_mae, mb_rmse = evaluate_predictions(median_preds, true)
print('Median Baseline  MAE: {:.4f}'.format(mb_mae))
print('Median Baseline RMSE: {:.4f}'.format(mb_rmse))
# Out:
# Median Baseline  MAE: 3.1265
# Median Baseline RMSE: 4.0630

# %% [markdown]
# ## Standard Machine Learning Models

# %%
# Evaluate several ml models by training on training set and testing on testing set
def evaluate(X_train, X_test, y_train, y_test):
    # Names of models
    model_name_list = ['Linear Regression', 'ElasticNet Regression',
                      'Random Forest', 'Extra Trees', 'SVM',
                       'Gradient Boosted', 'Baseline']
    X_train = X_train.drop(columns='B1')
    X_test = X_test.drop(columns='B1')
    
    # Instantiate the models
    model1 = LinearRegression()
    model2 = ElasticNet(alpha=1.0, l1_ratio=0.5)
    model3 = RandomForestRegressor(n_estimators=50)
    model4 = ExtraTreesRegressor(n_estimators=50)
    model5 = SVR(kernel='rbf', degree=3, C=1.0, gamma='auto')
    model6 = GradientBoostingRegressor(n_estimators=20)
    
    # Dataframe for results
    results = pd.DataFrame(columns=['mae', 'rmse'], index = model_name_list)
    
    # Train and predict with each model
    for i, model in enumerate([model1, model2, model3, model4, model5, model6]):
        model.fit(X_train, y_train)
        predictions = model.predict(X_test)
        
        # Metrics
        mae = np.mean(abs(predictions - y_test))
        rmse = np.sqrt(np.mean((predictions - y_test) ** 2))
        
        # Insert results into the dataframe
        model_name = model_name_list[i]
        results.loc[model_name, :] = [mae, rmse]
    
    # Median Value Baseline Metrics
    baseline = np.median(y_train)
    baseline_mae = np.mean(abs(baseline - y_test))
    baseline_rmse = np.sqrt(np.mean((baseline - y_test) ** 2))
    
    results.loc['Baseline', :] = [baseline_mae, baseline_rmse]
    
    return results

# %%
results = evaluate(X_train, X_test, y_train, y_test)

# %% [markdown]
# #### Visual Comparison of Models

# %%
figsize(12, 8)
matplotlib.rcParams['font.size'] = 16
# Root mean squared error
ax =  plt.subplot(1, 2, 1)
results.sort_values('mae', ascending = True).plot.bar(y = 'mae', color = 'b', ax = ax)
plt.title('Model Mean Absolute Error'); plt.ylabel('MAE');

# Median absolute percentage error
ax = plt.subplot(1, 2, 2)
results.sort_values('rmse', ascending = True).plot.bar(y = 'rmse', color = 'r', ax = ax)
plt.title('Model Root Mean Squared Error'); plt.ylabel('RMSE');

plt.tight_layout()

# %%
X_train
# Out:
#            V_1        V_2       V_3       V_4       V_5       V_6       V_7  \
# 82  -37.656657   0.813122  0.078257 -0.190456 -0.649145  0.230829  0.300561
# 991  74.956676  -7.598335 -2.868160  0.470730 -1.563229  1.363610 -1.842435
# 789   9.258307  12.323899  2.679987 -7.097378  3.793356 -5.028804 -0.181041
# 894  -0.376519  16.854372  1.199644  1.585636 -5.584093  5.478283 -0.557676
# 398  -6.858960  -4.207609 -2.785431  0.292426 -1.808812 -1.748866 -1.313337
# ..         ...        ...       ...       ...       ...       ...       ...
# 106 -29.254373   0.249444 -2.765213  1.469286 -5.648270 -2.296831  3.659698
# 270  10.900209 -18.794271  2.754089  3.861569 -0.931834  0.458945  1.578865
# 860  -2.199186  11.509345  7.935692 -1.940114 -2.839314 -5.194625  0.351941
# 435 -12.997473  -2.958303  2.150959  4.644765 -2.136106  2.533639 -1.201262
# 102   7.395904  13.393779  1.139169 -2.080353 -6.163762  5.631542  0.947643
#
#           V_8       V_9      V_10  ...     V_792     V_793     V_794  \
# 82  -0.738313  0.341207 -0.358029  ... -0.772667 -0.283585  0.405055
# 991  0.227660  0.842484 -0.254570  ... -1.408423 -0.779825 -1.695116
# 789 -1.268647 -1.974467  3.892336  ...  0.269356 -0.616298  0.302966
# 894 -0.283455 -1.216108 -3.910552  ...  0.159506 -0.097960 -0.480761
# 398  1.061112 -0.758927  1.142068  ...  0.117288  1.957967  0.023818
# ..        ...       ...       ...  ...       ...       ...       ...
# 106 -3.292339 -0.706319  3.353585  ...  0.228326  1.347871  1.348338
# 270  0.370900 -0.214380 -0.156112  ... -1.541787  1.110263 -0.496525
# 860 -0.119479  1.115986 -0.012550  ...  0.541526  0.137805 -0.441904
# 435  0.238884  0.959364  0.802395  ...  0.589491  0.617130 -0.407363
# 102 -1.635430  5.562092 -2.039911  ... -0.084267  0.113007  0.339995
#
#         V_795     V_796     V_797     V_798     V_799     V_800         B1
# 82   2.169412 -1.331407 -0.217850  0.453267 -2.651282  0.000448  10.201364
# 991  1.849223  0.561348  1.314294  0.687140  0.780081  0.158184  11.980224
# 789 -0.225021 -0.466914 -0.724807 -0.516026 -0.838902  0.174803  12.550562
# 894 -0.338025 -1.008908  0.108976 -0.093271 -0.069817  0.842426   8.257585
# 398 -0.062676 -0.451076 -0.091520 -0.200741  0.039032 -0.207157   9.850674
# ..        ...       ...       ...       ...       ...       ...        ...
# 106 -0.512189  1.908838  0.446021  0.440185 -0.957999  0.111552  11.029213
# 270  0.115552 -0.455193 -2.169910  0.825163  0.616341  0.513574  13.669175
# 860 -1.345909  0.435008 -0.251933  0.307254 -0.207064  0.565317  10.985618
# 435 -0.006114  0.231166 -0.628324 -0.343726 -0.641552 -0.613477   8.016081
# 102 -0.222648  0.899797  0.000774  0.133251 -0.219813 -0.144774   9.391285
#
# [750 rows x 801 columns]

# %%
results
# Out:
#                            mae     rmse
# Linear Regression      9.06021  11.8138
# ElasticNet Regression  2.34566  3.07984
# Random Forest          2.69422  3.47234
# Extra Trees             2.7275  3.52414
# SVM                    3.03578  3.96155
# Gradient Boosted       2.59765  3.38373
# Baseline               3.12653  4.06305

# %%
print('Gradient Boosted regressor is {:0.2f}% better than the baseline.'.format(
    (100 * abs(results.loc['Gradient Boosted', 'mae'] - results.loc['Baseline', 'mae'])) / results.loc['Baseline', 'mae']))
# Out:
# Gradient Boosted regressor is 16.92% better than the baseline.

# %% [markdown]
# ## Formula from Ordinary Least Squares Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train.drop(columns='B1'), y_train)

ols_formula = 'result = %0.2f +' % lr.intercept_
for i, col in enumerate(X_train.columns[:800]):
    ols_formula += ' %0.2f * %s +' % (lr.coef_[i], col)
    
' '.join(ols_formula.split(' ')[:-1])
# Out:
# 'result = 10.52 + -0.02 * V_1 + -0.13 * V_2 + 0.22 * V_3 + -0.38 * V_4 + 0.49 * V_5 + 0.02 * V_6 + -0.59 * V_7 + 0.07 * V_8 + -0.13 * V_9 + -0.24 * V_10 + -0.19 * V_11 + -0.13 * V_12 + -0.02 * V_13 + 0.14 * V_14 + -0.02 * V_15 + -0.19 * V_16 + 0.07 * V_17 + -0.15 * V_18 + -0.06 * V_19 + -0.09 * V_20 + -0.00 * V_21 + 0.13 * V_22 + -0.12 * V_23 + -0.25 * V_24 + -0.20 * V_25 + 0.20 * V_26 + 0.02 * V_27 + 0.13 * V_28 + -0.27 * V_29 + -0.08 * V_30 + 0.13 * V_31 + 0.11 * V_32 + 0.07 * V_33 + -0.06 * V_34 + 0.04 * V_35 + -0.08 * V_36 + -0.00 * V_37 + -0.10 * V_38 + -0.05 * V_39 + -0.13 * V_40 + 0.06 * V_41 + 0.27 * V_42 + 0.10 * V_43 + 0.09 * V_44 + 0.10 * V_45 + -0.03 * V_46 + 0.05 * V_47 + 0.12 * V_48 + -0.09 * V_49 + -0.14 * V_50 + -0.26 * V_51 + -0.00 * V_52 + 0.05 * V_53 + 0.05 * V_54 + 0.16 * V_55 + -0.14 * V_56 + 0.15 * V_57 + 0.02 * V_58 + -0.10 * V_59 + -0.04 * V_60 + 0.17 * V_61 + 0.10 * V_62 + 0.06 * V_63 + 0.14 * V_64 + 0.27 * V_65 + -0.00 * V_66 + -0.01 * V_67 + -0.27 * V_68 + 0.03 * V_69 + -0.00 * V_70 + -0.10 * V_71 + 0.01 * V_72 + -0.01 * V_73 + -0.20 * V_74 + 0.12 * V_75 + 0.04 * V_76 + -0.03 * V_77 + 0.01 * V_78 + -0.14 * V_79 + 0.32 * V_80 + -0.39 * V_81 + 0.12 * V_82 + -0.22 * V_83 + 0.18 * V_84 + -0.25 * V_85 + 0.03 * V_86 + 0.04 * V_87 + 0.00 * V_88 + 0.10 * V_89 + 0.08 * V_90 + 0.24 * V_91 + 0.12 * V_92 + 0.35 * V_93 + -0.41 * V_94 + 0.06 * V_95 + -0.08 * V_96 + 0.08 * V_97 + -0.15 * V_98 + 0.02 * V_99 + 0.05 * V_100 + 0.12 * V_101 + 0.10 * V_102 + -0.09 * V_103 + 0.03 * V_104 + -0.05 * V_105 + 0.10 * V_106 + 0.00 * V_107 + 0.05 * V_108 + 0.03 * V_109 + 0.06 * V_110 + -0.26 * V_111 + 0.07 * V_112 + 0.12 * V_113 + 0.11 * V_114 + -0.03 * V_115 + -0.01 * V_116 + -0.06 * V_117 + -0.29 * V_118 + 0.06 * V_119 + -0.15 * V_120 + -0.07 * V_121 + -0.11 * V_122 + -0.17 * V_123 + 0.08 * V_124 + -0.03 * V_125 + 0.06 * V_126 + -0.08 * V_127 + -0.10 * V_128 + -0.11 * V_129 + -0.14 * V_130 + -0.03 * V_131 + 0.04 * V_132 + -0.17 * V_133 + 0.01 * V_134 + 0.14 * V_135 + 0.06 * V_136 + 0.10 * V_137 + 0.05 * V_138 + -0.03 * V_139 + -0.08 * V_140 + -0.21 * V_141 + 0.01 * V_142 + -0.09 * V_143 + -0.04 * V_144 + 0.05 * V_145 + -0.07 * V_146 + -0.13 * V_147 + 0.22 * V_148 + -0.10 * V_149 + 0.14 * V_150 + -0.21 * V_151 + -0.20 * V_152 + 0.10 * V_153 + -0.08 * V_154 + 0.04 * V_155 + -0.11 * V_156 + 0.13 * V_157 + 0.22 * V_158 + 0.03 * V_159 + -0.01 * V_160 + -0.04 * V_161 + -0.02 * V_162 + 0.01 * V_163 + 0.01 * V_164 + -0.14 * V_165 + -0.14 * V_166 + -0.04 * V_167 + -0.15 * V_168 + -0.17 * V_169 + 0.04 * V_170 + -0.10 * V_171 + 0.01 * V_172 + 0.05 * V_173 + 0.00 * V_174 + -0.07 * V_175 + -0.01 * V_176 + -0.12 * V_177 + 0.11 * V_178 + 0.05 * V_179 + -0.11 * V_180 + 0.00 * V_181 + -0.07 * V_182 + -0.02 * V_183 + -0.22 * V_184 + -0.05 * V_185 + -0.11 * V_186 + 0.03 * V_187 + 0.19 * V_188 + -0.21 * V_189 + -0.23 * V_190 + -0.09 * V_191 + -0.10 * V_192 + -0.00 * V_193 + 0.01 * V_194 + 0.21 * V_195 + 0.21 * V_196 + -0.12 * V_197 + 0.07 * V_198 + -0.04 * V_199 + -0.10 * V_200 + -0.15 * V_201 + -0.03 * V_202 + -0.07 * V_203 + -0.14 * V_204 + 0.15 * V_205 + 0.25 * V_206 + 0.13 * V_207 + -0.05 * V_208 + -0.02 * V_209 + -0.15 * V_210 + 0.05 * V_211 + -0.00 * V_212 + -0.10 * V_213 + 0.02 * V_214 + 0.10 * V_215 + 0.06 * V_216 + 0.03 * V_217 + 0.03 * V_218 + -0.04 * V_219 + 0.12 * V_220 + 0.13 * V_221 + -0.10 * V_222 + -0.20 * V_223 + 0.07 * V_224 + 0.07 * V_225 + -0.07 * V_226 + -0.05 * V_227 + -0.07 * V_228 + -0.23 * V_229 + -0.13 * V_230 + 0.02 * V_231 + -0.03 * V_232 + -0.09 * V_233 + -0.15 * V_234 + 0.16 * V_235 + 0.03 * V_236 + 0.05 * V_237 + 0.05 * V_238 + 0.03 * V_239 + 0.06 * V_240 + 0.10 * V_241 + -0.11 * V_242 + -0.09 * V_243 + -0.06 * V_244 + 0.11 * V_245 + 0.16 * V_246 + 0.10 * V_247 + -0.12 * V_248 + 0.05 * V_249 + -0.06 * V_250 + -0.15 * V_251 + 0.03 * V_252 + -0.11 * V_253 + 0.01 * V_254 + 0.12 * V_255 + 0.14 * V_256 + -0.26 * V_257 + -0.12 * V_258 + 0.03 * V_259 + 0.21 * V_260 + -0.35 * V_261 + 0.07 * V_262 + -0.21 * V_263 + -0.26 * V ...

# %%
print(lr)
print('coef_', lr.coef_)
print('intercept', lr.intercept_)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# coef_ [-1.82540560e-02 -1.34540025e-01  2.24285712e-01 -3.76368621e-01
#   4.86993775e-01  1.97898314e-02 -5.87796272e-01  7.00275552e-02
#  -1.26997008e-01 -2.36948648e-01 -1.86645680e-01 -1.26946104e-01
#  -1.66424795e-02  1.37400880e-01 -2.31696578e-02 -1.88106502e-01
#   7.19193443e-02 -1.49801228e-01 -6.15565511e-02 -9.25072943e-02
#  -2.75412582e-03  1.33118423e-01 -1.20492776e-01 -2.48689238e-01
#  -2.02528900e-01  2.01433639e-01  2.30053149e-02  1.28454308e-01
#  -2.74708872e-01 -7.86776701e-02  1.33430580e-01  1.07573731e-01
#   7.39479518e-02 -5.66612124e-02  3.60095887e-02 -8.32063489e-02
#  -7.46068665e-04 -9.56743869e-02 -5.40628908e-02 -1.30570864e-01
#   5.53871472e-02  2.69491947e-01  1.03480346e-01  9.44129438e-02
#   1.04720792e-01 -3.04298291e-02  5.49493214e-02  1.20147875e-01
#  -9.05887055e-02 -1.35083869e-01 -2.55794088e-01 -1.01317983e-03
#   4.58458464e-02  4.99388620e-02  1.60203635e-01 -1.37302594e-01
#   1.50792238e-01  2.21870599e-02 -9.95462654e-02 -3.82383294e-02
#   1.73313083e-01  1.01198845e-01  5.62086812e-02  1.41350450e-01
#   2.65804371e-01 -4.83995954e-03 -1.06704495e-02 -2.68915721e-01
#   3.02610285e-02 -6.33836257e-04 -9.73893634e-02  1.49504885e-02
#  -9.23641031e-03 -2.03320723e-01  1.15833360e-01  3.95971555e-02
#  -2.90755153e-02  9.99883455e-03 -1.38884332e-01  3.18387995e-01
#  -3.85512740e-01  1.19240088e-01 -2.18314513e-01  1.83803617e-01
#  -2.54861611e-01  2.72688860e-02  4.40753047e-02  2.72716937e-03
#   9.92185870e-02  8.28015079e-02  2.39455258e-01  1.24369871e-01
#   3.51107958e-01 -4.11675807e-01  6.00551382e-02 -8.45833761e-02
#   8.23759696e-02 -1.46174878e-01  1.69058454e-02  5.49146072e-02
#   1.15498367e-01  1.00518005e-01 -9.01455803e-02  2.85505661e-02
#  -4.77017976e-02  9.56260623e-02  1.29355905e-03  5.27072657e-02
#   2.93148025e-02  6.41314366e-02 -2.62176144e-01  7.37716394e-02
#   1.22105653e-01  1.13616917e-01 -2.53962762e-02 -5.44376909e-03
#  -5.92344298e-02 -2.92769781e-01  5.58457349e-02 -1.53261247e-01
#  -7.38574698e-02 -1.07932042e-01 -1.74635586e-01  7.88987840e-02
#  -3.31298417e-02  6.10306881e-02 -7.96210343e-02 -1.00301705e-01
#  -1.14551438e-01 -1.39124563e-01 -2.51631337e-02  3.90646302e-02
#  -1.73999817e-01  9.96063775e-03  1.44332447e-01  5.57351584e-02
#   9.74972290e-02  4.52985740e-02 -2.65691010e-02 -8.26269099e-02
#  -2.05096605e-01  9.21104333e-03 -8.90215287e-02 -3.58066078e-02
#   4.56622976e-02 -7.02179950e-02 -1.33029411e-01  2.23864630e-01
#  -9.72056479e-02  1.36263409e-01 -2.10334671e-01 -2.04658869e-01
#   1.04132204e-01 -8.15306024e-02  3.83370717e-02 -1.09678990e-01
#   1.31112235e-01  2.18825117e-01  3.36499611e-02 -1.38335284e-02
#  -4.35769573e-02 -2.21230002e-02  1.18912299e-02  7.19588858e-03
#  -1.35857352e-01 -1.36265123e-01 -3.76054168e-02 -1.47650788e-01
#  -1.73419498e-01  4.01938944e-02 -1.04276247e-01  1.43522558e-02
#   5.31368057e-02  1.65242314e-03 -7.28206168e-02 -6.44084428e-03
#  -1.20928523e-01  1.05728760e-01  4.99339459e-02 -1.10522627e-01
#   3.60346326e-03 -7.47634741e-02 -2.25172102e-02 -2.22677103e-01
#  -4.81255187e-02 -1.05898600e-01  2.62706292e-02  1.94607876e-01
#  -2.05527237e-01 -2.27092955e-01 -8.84650942e-02 -9.97733625e-02
#  -3.84212472e-03  1.19476666e-02  2.09162520e-01  2.10405006e-01
#  -1.19037251e-01  6.82869837e-02 -4.47344443e-02 -1.02267419e-01
#  -1.49587198e-01 -2.71166150e-02 -7.22600437e-02 -1.41738692e-01
#   1.53424648e-01  2.47121241e-01  1.25919390e-01 -4.95719333e-02
#  -1.85888179e-02 -1.47613214e-01  5.06315268e-02 -4.72447854e-03
#  -1.02548020e-01  1.54423156e-02  1.01361463e-01  5.53197528e-02
#   2.52949197e-02  2.88833726e-02 -3.62629463e-02  1.21656512e-01
#   1.27101847e-01 -9.90260071e-02 -1.98523547e-01  6.72130891e-02
#   7.08168218e-02 -6.89396139e-02 -5.47729726e-02 -7.43657276e-02
#  -2.28058990e-01 -1.29181516e-01  2.21688788e-02 -2.57935282e-02
#  -8.63450828e-02 -1.48367659e-01  1.55417230e-01  2.88317067e-02
#   5.03890966e-02  5.43137011e-02  3.40787629e-02  6.42292606e-02
#   1.01468489e-01 -1.11370807e-01 -9.01653180e-02 -6.37595882e-02
#   1.11467362e-01  1.61346044e-01  9.65428332e-02 -1.17831336e-01
#   5.23128397e-02 -6.23232886e-02 -1.47326829e-01  3.28347093e-02
#  -1.11477289e-01  6.40434398e-03  1.21878902e-01  1.39122381e-01
#  -2.57819292e-01 -1.17009574e-01  2.86360465e-02  2.08828105e-01
#  -3.47863227e-01  7.45479149e-02 -2.11737969e-01 -2.61881425e-01
#  -2.28245957e-01 -6.66023297e-02 -1.39433634e-01 -2.07657661e-01
#   2.29681559e-02 -2.06167180e-02  1.29937113e-01  3.21079165e-02
#  -1.02724275e-02  4.47218781e-02  1.06488684e-01  9.86276840e-02
#  -2.68088460e-01  5.33704651e-02 -1.52138862e-01 -5.23428982e-02
#  -3.26991446e-01  5.66666141e-02 -8.76692161e-02 -8.32967122e-02
#  -1.43148523e-01 -4.29982173e-03  1.27388543e-01 -1.56201696e-01
#   1.12039358e-01  2.78270488e-01  1.67545069e-01 -1.14339385e-01
#   1.86762365e-02  2.68062968e-02 -2.14110923e-01 -7.68735588e-02
#  -1.19322471e-01 -1.39047186e-01  1.40513606e-01 -5.49522624e-02
#  -2.38378453e-04  2.11998949e-01 -6.15601302e-02 -1.41877415e-01
#   2.34603395e-01  3.07226896e-02  1.43581452e-02  2.10221937e-01
#  -5.28477717e-02  1.42707541e-01  5.25024699e-02 -8.55667498e-02
#   1.60582259e-01  2.36219377e-03 -8.96994706e-03  2.74970863e-01
#  -1.30243024e-02 -2.92129439e-03 -2.72476266e-01  1.59829460e-01
#   1.14866481e-01 -2.61312222e-02 -1.87995045e-01 -4.05910023e-02
#   4.89475069e-02  2.17066207e-01 -7.34560164e-03  2.25431011e-01
#   1.28694626e-01 -4.94712273e-02 -1.53010026e-01  1.39052000e-01
#   2.98359319e-02  1.98412374e-01  1.56599858e-03  2.78262711e-01
#  -1.17150612e-02 -1.29156135e-01 -2.55792540e-01 -1.57967323e-01
#   1.33567488e-01  6.27638392e-02 -1.63730764e-01  4.15619535e-01
#   1.12479473e-01 -1.48925793e-01 -1.14358285e-01  9.74148802e-02
#  -5.71007860e-02  1.44211315e-02  5.19604158e-02 -5.13006065e-02
#   4.98958765e-02  5.40450049e-02 -5.59691126e-02 -4.08296002e-02
#  -1.73703571e-01  6.48271822e-03  6.51244111e-02  1.07170436e-01
#  -2.11698240e-01 -1.61364733e-01 -1.41579496e-01  1.84851081e-01
#  -5.84375398e-03 -1.46977122e-01 -4.31907939e-02 -1.96614416e-01
#  -3.96930473e-02 -8.87680955e-02  1.71585468e-01 -2.01613707e-02
#   6.83465122e-02 -2.15049482e-02 -1.41439772e-02  1.39662953e-01
#   1.19160840e-01  4.05188947e-04  1.06230647e-01 -1.52949641e-01
#  -1.74039510e-01  1.14343832e-02  2.14577374e-01 -4.61867153e-02
#   2.20775187e-02  7.69137172e-02  3.40543346e-02 -7.13208762e-02
#  -1.92864318e-02 -2.34538729e-01 -2.81194916e-03  7.05040627e-02
#   9.11970047e-02  5.14675786e-02  6.50041933e-02  5.43906144e-02
#   2.43448613e-02  3.84000276e-02  4.88689928e-02 -3.07992564e-02
#   4.20479975e-02  1.28167053e-01 -5.91286256e-02 -1.59734597e-02
#   1.88112286e-01 -7.95196050e-02  2.38504636e-01  1.62904322e-01
#   6.84470563e-02 -3.82914561e-02 -2.91894857e-01 -1.29412096e-01
#  -1.22729984e-01 -7.45415791e-02  1.25931722e-01 -3.04573867e-02
#  -1.12491926e-02  9.00325945e-02  2.40155864e-02  5.38423649e-02
#   2.42057373e-01  1.40311437e-01 -1.13411138e-01  1.10180235e-02
#  -1.31920013e-01 -1.16858367e-01  1.28384647e-01 -1.93171042e-01
#  -4.18216342e-02  1.56817126e-01  1.08786889e-02 -3.98720643e-01
#  -4.49982675e-02  4.79606781e-01 -1.11388830e-01  1.59833851e-02
#   8.38917500e-02  3.25362997e-02  1.44943453e-01 -1.69500661e-02
#   1.81092459e-01 -6.85474149e-02 -1.29089330e-01  1.80669043e-02
#  -5.75556141e-03  6.57612946e-02 -3.41146963e-01 -1.03214309e-01
#   1.81870652e-02 -2.35305709e-02  1.01303038e-01  1.80147074e-01
#  -1.12390152e-01  4.91126890e-02  1.63179633e-01 -1.72759973e-01
#   6.41504294e-02 -2.18793601e-02  1.94672398e-01  2.09281176e-01
#   9.17993861e-02 -1.15195050e-01  8.20144099e-03  1.02872941e-01
#  -5.67705529e-02  1.96234404e-01  1.35993952e-01 -9.71654961e-02
#  -2.23506277e-01 -1.31400140e-01 -1.29959340e-01  1.17186303e-01
#   6.61405698e-03 -5.46705439e-02  6.77284288e-02  1.99332570e-01
#   5.44138646e-02  1.20066970e-02  1.46214970e-01  2.15166996e-01
#   7.77184341e-02  2.86922318e-02 -7.88989644e-02 -1.30854002e-02
#  -3.15405403e-02 -5.47186549e-02 -4.37311049e-02  6.53724323e-02
#  -1.22089533e-01  1.03172315e-01 -6.60955034e-02 -1.99340458e-01
#   2.16281045e-01  5.39416160e-02 -4.30248943e-02 -4.89264184e-02
#  -1.32780851e-01  1.70933600e-01  3.23647624e-02  7.70567295e-02
#  -3.86325440e-02 -9.55603216e-02  1.03497591e-02  1.59965365e-02
#  -2.22418682e-01 -7.11789021e-02 -8.95705580e-02  1.96808137e-01
#  -2.13059165e-01 -1.66586974e-01  1.49348432e-01 -6.54422327e-02
#   3.59883224e-02  8.56501823e-02  1.18769877e-02 -5.90853551e-02
#   1.77468745e-01  3.38661884e-02 -6.56198620e-02  6.10945558e-02
#  -2.23854248e-02 -1.64283232e-01  1.32729161e-01 -4.42464781e-02
#   2.43454132e-02 -6.46627772e-02  1.29269537e-01  1.93439452e-01
#  -5.91422301e-02  5.45224391e-02  1.33422255e-01  2.52681125e-02
#  -3.56049010e-02 -5.59978131e-02 -1.19996713e-02  1.00002756e-02
#  -6.97155645e-02  1.42876741e-01  2.08839723e-01  3.96477798e-02
#   1.09450667e-01 -5.43108953e-02  1.06800057e-01  1.18615124e-02
#  -5.40249580e-01  4.60576457e-03  1.57367339e-01 -2.99849690e-01
#   8.84100213e-02 -4.22914479e-02 -1.54122708e-01  3.79306239e-03
#  -1.10547106e-01 -4.90707646e-02  1.30607277e-01  2.65561870e-01
#   1.62641950e-01 -1.47202064e-01  1.67806716e-01  1.74309753e-02
#   5.66270000e-02  5.30837395e-02 -1.68287821e-01  2.26025855e-03
#  -2.45026163e-02  1.96176944e-01  6.85707026e-02  1.65310231e-01
#  -1.04771144e-01  2.60623326e-02 -6.27230918e-02  8.76262199e-02
#   2.55904599e-03 -1.64887860e-03  1.53450647e-01  2.79064200e-02
#   1.95346741e-02 -4.94677047e-02 -1.45050325e-02 -1.56580531e-01
#  -1.20644233e-01  1.89025874e-02 -8.41529038e-02 -2.06297721e-01
#  -1.15614500e-01  1.77954478e-01  4.89304116e-02  1.03233760e-01
#  -1.24969554e-02 -1.17310359e-01 -1.36571082e-01  4.18579819e-02
#   1.46696354e-01 -1.53268569e-01 -2.03470600e-01 -2.69739656e-02
#   2.35570614e-01  3.86014291e-01  1.14553298e-02 -4.37856222e-02
#   2.03422048e-01 -3.36573665e-01  1.77350729e-01  7.23109149e-02
#   3.13772576e-01  5.58504018e-02  2.25702920e-01 -5.77547355e-02
#  -1.23333911e-01 -3.81758267e-01  2.04837710e-01  5.74030387e-02
#  -3.87488951e-03 -3.30315837e-01  9.98674845e-02  1.67571492e-01
#   7.77342815e-02  1.79332352e-01 -2.52665252e-01  1.70768266e-01
#  -4.65199800e-02  2.28353707e-01 -1.41377382e-01 -4.42604388e-02
#  -6.87584249e-02 -4.72960697e-02 -1.94002034e-01  1.11782111e-01
#   2.31991626e-01  2.63697996e-01 -3.01721828e-02 -2.02068248e-02
#  -1.43605390e-01 -2.06533435e-02 -7.70852880e-02 -1.87281123e-01
#   3.54333179e-01  1.93408690e-01  1.46680337e-01  1.92285957e-01
#   3.45834126e-02 -3.55982852e-01 -1.67961453e-01 -2.38427159e-02
#   1.18172533e-01 -1.48211846e-01  4.86507346e-02 -1.90605349e-01
#  -8.04960658e-02 -1.11423649e-01  1.57535194e-01 -5.01168611e-01
#   2.49178531e-01  5.38057519e-02 -2.95441953e-01  2.23792276e-01
#   2.00639879e-01 -4.14584277e-02 -1.34151998e-01  1.88275729e-01
#   1.35959651e-01  5.18475128e-02  1.53260601e-01  5.07700102e-01
#  -1.02498667e-02 -1.10633266e-01 -1.39093869e-01  8.49162266e-02
#  -1.10761494e-01  5.36844637e-03  4.22185669e-02  1.17175310e-01
#  -9.85896108e-02 -2.16337495e-01 -1.97019631e-01 -1.22715125e-01
#  -2.75254698e-01 -1.01735272e-01  7.27981186e-02 -1.70658243e-01
#   4.57130117e-02 -3.17849227e-02  3.19235987e-01  3.40580856e-02
#   7.61172815e-02  1.92116027e-02 -2.07928281e-01 -1.53122690e-02
#   3.85383839e-02  1.21204141e-01  2.83659562e-01 -1.17453148e-02
#   2.02632671e-02 -1.67713148e-02 -1.59537517e-02  2.75426560e-01
#   3.03274490e-01  4.16315196e-02 -2.63453971e-01  1.59815948e-01
#  -6.65172038e-02  6.95917324e-02 -3.65475723e-01  1.75888072e-01
#   1.08301150e-01  2.11375142e-01 -1.03228564e-01  1.66316185e-01
#   1.27250096e-01 -4.76479888e-02 -1.15370901e-01  7.66302686e-02
#   1.18156126e-01 -3.95611325e-02  1.31521737e-01  2.30356555e-01
#  -5.18540938e-02  2.26687033e-01 -1.17653092e-01  7.61800356e-03
#   8.52074395e-02  8.93569775e-02  1.49251751e-01 -3.88917847e-02
#   1.88006487e-02  4.37994046e-03 -1.88660530e-01  3.44756524e-02
#  -1.73281848e-01 -1.36614824e-01  6.12973459e-02 -3.21151610e-01
#  -3.80961948e-01  7.08624034e-02 -9.45152771e-02 -2.02888504e-01
#  -2.88749478e-01 -9.51212297e-02 -1.42814180e-01 -7.90427937e-02
#   6.11480741e-02 -1.68861226e-01  5.27476354e-02  3.74052410e-02
#   1.99154480e-01  1.22053413e-01  1.63281671e-01  2.14279814e-01
#   3.02278122e-01 -4.08785232e-02  2.26104961e-01  5.96565393e-03
#  -1.68922043e-01  1.75777189e-01 -1.22365857e-01  2.22585001e-01
#  -1.03887839e-01 -2.32286925e-01 -1.26626702e-01 -1.74828182e-01
#   1.78143524e-01 -2.59876489e-01  1.35274133e-01  2.10303299e-02
#  -7.81324795e-03  6.55287139e-02  1.76139258e-01  1.58600290e-01
#   5.14718146e-02  2.08766356e-01 -8.13257302e-02 -5.03469797e-02
#  -9.70647881e-02  4.15634638e-02  2.84770324e-01  4.35402399e-01
#  -2.28131862e-01 -2.33577634e-01 -3.18995593e-02  6.47444291e-02
#   9.59755197e-02  4.43756127e-03 -4.57015827e-01 -1.80474423e-01
#   2.52756532e-01  7.31700172e-02  6.82153159e-02 -1.46005180e-01
#   9.39974796e-02  8.83485337e-02  1.48816057e-01 -9.27240926e-04
#   3.93410261e-02 -3.22745980e-02 -2.09432270e-01  3.04209197e-01
#  -2.17066722e-01  1.10008966e-01  2.02064433e-01  1.83856609e-01]
# intercept 10.515893874364552

# %% [markdown]
# # Implementing Bayesian Linear Regression

# %%
# Formula for Bayesian Linear Regression (follows R formula syntax
formula = 'B1 ~ ' + ' + '.join(['%s' % variable for variable in X_train.columns[:800]])
formula
# Out:
# 'B1 ~ V_1 + V_2 + V_3 + V_4 + V_5 + V_6 + V_7 + V_8 + V_9 + V_10 + V_11 + V_12 + V_13 + V_14 + V_15 + V_16 + V_17 + V_18 + V_19 + V_20 + V_21 + V_22 + V_23 + V_24 + V_25 + V_26 + V_27 + V_28 + V_29 + V_30 + V_31 + V_32 + V_33 + V_34 + V_35 + V_36 + V_37 + V_38 + V_39 + V_40 + V_41 + V_42 + V_43 + V_44 + V_45 + V_46 + V_47 + V_48 + V_49 + V_50 + V_51 + V_52 + V_53 + V_54 + V_55 + V_56 + V_57 + V_58 + V_59 + V_60 + V_61 + V_62 + V_63 + V_64 + V_65 + V_66 + V_67 + V_68 + V_69 + V_70 + V_71 + V_72 + V_73 + V_74 + V_75 + V_76 + V_77 + V_78 + V_79 + V_80 + V_81 + V_82 + V_83 + V_84 + V_85 + V_86 + V_87 + V_88 + V_89 + V_90 + V_91 + V_92 + V_93 + V_94 + V_95 + V_96 + V_97 + V_98 + V_99 + V_100 + V_101 + V_102 + V_103 + V_104 + V_105 + V_106 + V_107 + V_108 + V_109 + V_110 + V_111 + V_112 + V_113 + V_114 + V_115 + V_116 + V_117 + V_118 + V_119 + V_120 + V_121 + V_122 + V_123 + V_124 + V_125 + V_126 + V_127 + V_128 + V_129 + V_130 + V_131 + V_132 + V_133 + V_134 + V_135 + V_136 + V_137 + V_138 + V_139 + V_140 + V_141 + V_142 + V_143 + V_144 + V_145 + V_146 + V_147 + V_148 + V_149 + V_150 + V_151 + V_152 + V_153 + V_154 + V_155 + V_156 + V_157 + V_158 + V_159 + V_160 + V_161 + V_162 + V_163 + V_164 + V_165 + V_166 + V_167 + V_168 + V_169 + V_170 + V_171 + V_172 + V_173 + V_174 + V_175 + V_176 + V_177 + V_178 + V_179 + V_180 + V_181 + V_182 + V_183 + V_184 + V_185 + V_186 + V_187 + V_188 + V_189 + V_190 + V_191 + V_192 + V_193 + V_194 + V_195 + V_196 + V_197 + V_198 + V_199 + V_200 + V_201 + V_202 + V_203 + V_204 + V_205 + V_206 + V_207 + V_208 + V_209 + V_210 + V_211 + V_212 + V_213 + V_214 + V_215 + V_216 + V_217 + V_218 + V_219 + V_220 + V_221 + V_222 + V_223 + V_224 + V_225 + V_226 + V_227 + V_228 + V_229 + V_230 + V_231 + V_232 + V_233 + V_234 + V_235 + V_236 + V_237 + V_238 + V_239 + V_240 + V_241 + V_242 + V_243 + V_244 + V_245 + V_246 + V_247 + V_248 + V_249 + V_250 + V_251 + V_252 + V_253 + V_254 + V_255 + V_256 + V_257 + V_258 + V_259 + V_260 + V_261 + V_262 + V_263 + V_264 + V_265 + V_266 + V_267 + V_268 + V_269 + V_270 + V_271 + V_272 + V_273 + V_274 + V_275 + V_276 + V_277 + V_278 + V_279 + V_280 + V_281 + V_282 + V_283 + V_284 + V_285 + V_286 + V_287 + V_288 + V_289 + V_290 + V_291 + V_292 + V_293 + V_294 + V_295 + V_296 + V_297 + V_298 + V_299 + V_300 + V_301 + V_302 + V_303 + V_304 + V_305 + V_306 + V_307 + V_308 + V_309 + V_310 + V_311 + V_312 + V_313 + V_314 + V_315 + V_316 + V_317 + V_318 + V_319 + V_320 + V_321 + V_322 + V_323 + V_324 + V_325 + V_326 + V_327 + V_328 + V_329 + V_330 + V_331 + V_332 + V_333 + V_334 + V_335 + V_336 + V_337 + V_338 + V_339 + V_340 + V_341 + V_342 + V_343 + V_344 + V_345 + V_346 + V_347 + V_348 + V_349 + V_350 + V_351 + V_352 + V_353 + V_354 + V_355 + V_356 + V_357 + V_358 + V_359 + V_360 + V_361 + V_362 + V_363 + V_364 + V_365 + V_366 + V_367 + V_368 + V_369 + V_370 + V_371 + V_372 + V_373 + V_374 + V_375 + V_376 + V_377 + V_378 + V_379 + V_380 + V_381 + V_382 + V_383 + V_384 + V_385 + V_386 + V_387 + V_388 + V_389 + V_390 + V_391 + V_392 + V_393 + V_394 + V_395 + V_396 + V_397 + V_398 + V_399 + V_400 + V_401 + V_402 + V_403 + V_404 + V_405 + V_406 + V_407 + V_408 + V_409 + V_410 + V_411 + V_412 + V_413 + V_414 + V_415 + V_416 + V_417 + V_418 + V_419 + V_420 + V_421 + V_422 + V_423 + V_424 + V_425 + V_426 + V_427 + V_428 + V_429 + V_430 + V_431 + V_432 + V_433 + V_434 + V_435 + V_436 + V_437 + V_438 + V_439 + V_440 + V_441 + V_442 + V_443 + V_444 + V_445 + V_446 + V_447 + V_448 + V_449 + V_450 + V_451 + V_452 + V_453 + V_454 + V_455 + V_456 + V_457 + V_458 + V_459 + V_460 + V_461 + V_462 + V_463 + V_464 + V_465 + V_466 + V_467 + V_468 + V_469 + V_470 + V_471 + V_472 + V_473 + V_474 + V_475 + V_476 + V_477 + V_478 + V_479 + V_480 + V_481 + V_482 + V_483 + V_484 + V_485 + V_486 + V_487 + V_488 + V_489 + V_490 + V_491 + V_492 + V_493 + V_494 + V_495 + V_496 + V_497 + V_498 + V_499 + V_500 + V_501 + V_502 + V_503 + V_504 + V_505 + V_506 + V_507 + V_508 + V_509 + V_510 + V_511 + V_512 + V_513  ...

# %% [markdown]
# ## Create Model in PyMC3 and Sample from Posterior
#
# We now build the model using the formula defined above and a normal distribution for the data likelihood. Then, we let a Markov Chain Monte Carlo algorithm draw samples from the posterior to approximate the posterior for each of the model parameters.

# %%
# Context for the model
with pm.Model() as normal_model:
    
    # The prior for the model parameters will be a normal distribution
    family = pm.glm.families.Normal()
    
    # Creating the model requires a formula and data (and optionally a family)
    pm.GLM.from_formula(formula, data = X_train, family = family)
    
    # Perform Markov Chain Monte Carlo sampling
    normal_trace = pm.sample(draws=2000, chains = 2, tune = 500, cores=-1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [sd, V_800, V_799, V_798, V_797, V_796, V_795, V_794, V_793, V_792, V_791, V_790, V_789, V_788, V_787, V_786, V_785, V_784, V_783, V_782, V_781, V_780, V_779, V_778, V_777, V_776, V_775, V_774, V_773, V_772, V_771, V_770, V_769, V_768, V_767, V_766, V_765, V_764, V_763, V_762, V_761, V_760, V_759, V_758, V_757, V_756, V_755, V_754, V_753, V_752, V_751, V_750, V_749, V_748, V_747, V_746, V_745, V_744, V_743, V_742, V_741, V_740, V_739, V_738, V_737, V_736, V_735, V_734, V_733, V_732, V_731, V_730, V_729, V_728, V_727, V_726, V_725, V_724, V_723, V_722, V_721, V_720, V_719, V_718, V_717, V_716, V_715, V_714, V_713, V_712, V_711, V_710, V_709, V_708, V_707, V_706, V_705, V_704, V_703, V_702, V_701, V_700, V_699, V_698, V_697, V_696, V_695, V_694, V_693, V_692, V_691, V_690, V_689, V_688, V_687, V_686, V_685, V_684, V_683, V_682, V_681, V_680, V_679, V_678, V_677, V_676, V_675, V_674, V_673, V_672, V_671, V_670, V_669, V_668, V_667, V_666, V_665, V_664, V_663, V_662, V_661, V_660, V_659, V_658, V_657, V_656, V_655, V_654, V_653, V_652, V_651, V_650, V_649, V_648, V_647, V_646, V_645, V_644, V_643, V_642, V_641, V_640, V_639, V_638, V_637, V_636, V_635, V_634, V_633, V_632, V_631, V_630, V_629, V_628, V_627, V_626, V_625, V_624, V_623, V_622, V_621, V_620, V_619, V_618, V_617, V_616, V_615, V_614, V_613, V_612, V_611, V_610, V_609, V_608, V_607, V_606, V_605, V_604, V_603, V_602, V_601, V_600, V_599, V_598, V_597, V_596, V_595, V_594, V_593, V_592, V_591, V_590, V_589, V_588, V_587, V_586, V_585, V_584, V_583, V_582, V_581, V_580, V_579, V_578, V_577, V_576, V_575, V_574, V_573, V_572, V_571, V_570, V_569, V_568, V_567, V_566, V_565, V_564, V_563, V_562, V_561, V_560, V_559, V_558, V_557, V_556, V_555, V_554, V_553, V_552, V_551, V_550, V_549, V_548, V_547, V_546, V_545, V_544, V_543, V_542, V_541, V_540, V_539, V_538, V_537, V_536, V_535, V_534, V_533, V_532, V_531, V_530, V_529, V_528, V_527, V_526, V_525, V_524, V_523, V_522, V_521, V_520, V_519, V_518, V_517, V_516, V_515, V_514, V_513, V_512, V_511, V_510, V_509, V_508, V_507, V_506, V_505, V_504, V_503, V_502, V_501, V_500, V_499, V_498, V_497, V_496, V_495, V_494, V_493, V_492, V_491, V_490, V_489, V_488, V_487, V_486, V_485, V_484, V_483, V_482, V_481, V_480, V_479, V_478, V_477, V_476, V_475, V_474, V_473, V_472, V_471, V_470, V_469, V_468, V_467, V_466, V_465, V_464, V_463, V_462, V_461, V_460, V_459, V_458, V_457, V_456, V_455, V_454, V_453, V_452, V_451, V_450, V_449, V_448, V_447, V_446, V_445, V_444, V_443, V_442, V_441, V_440, V_439, V_438, V_437, V_436, V_435, V_434, V_433, V_432, V_431, V_430, V_429, V_428, V_427, V_426, V_425, V_424, V_423, V_422, V_421, V_420, V_419, V_418, V_417, V_416, V_415, V_414, V_413, V_412, V_411, V_410, V_409, V_408, V_407, V_406, V_405, V_404, V_403, V_402, V_401, V_400, V_399, V_398, V_397, V_396, V_395, V_394, V_393, V_392, V_391, V_390, V_389, V_388, V_387, V_386, V_385, V_384, V_383, V_382, V_381, V_380, V_379, V_378, V_377, V_376, V_375, V_374, V_373, V_372, V_371, V_370, V_369, V_368, V_367, V_366, V_365, V_364, V_363, V_362, V_361, V_360, V_359, V_358, V_357, V_356, V_355, V_354, V_353, V_352, V_351, V_350, V_349, V_348, V_347, V_346, V_345, V_344, V_343, V_342, V_341, V_340, V_339, V_338, V_337, V_336, V_335, V_334, V_333, V_332, V_331, V_330, V_329, V_328, V_327, V_326, V_325, V_324, V_323, V_322, V_321, V_320, V_319, V_318, V_317, V_316, V_315, V_314, V_313, V_312, V_311, V_310, V_309, V_308, V_307, V_306, V_305, V_304, V_303, V_302, V_301, V_300, V_299, V_298, V_297, V_296, V_295, V_294, V_293, V_292, V_291, V_290, V_289, V_288, V_287, V_286, V_285, V_284, V_283, V_282, V_281, V_280, V_279, V_278, V_277, V_276, V_275, V_274, V_273, V_272, V_271, V_270, V_269, V_268, V_267, V_266, V_265, V_264, V_263, V_262, V_261, V_260, V_259, V_258, V_257, V_256, V_255, V_254, V_253, V_252, V_251, V_250, V_249, V_248, V_247, V_246, V_245, V_244, V_243, V_242, V_241, V_240, V_239, V_238, V_237, V_236, V_235, V_234, V_233, V_232, V_231, ...
# Sampling chain 0, 22 divergences: 100%|██████████| 2500/2500 [2:43:59<00:00,  3.94s/it]
# Sampling chain 1, 0 divergences:  27%|██▋       | 686/2500 [37:29<2:24:16,  4.77s/it]

# %%
import sys

sys.setrecursionlimit(100000)

# %% [markdown]
# # Examine Bayesian Linear Regression Results

# %% [markdown]
# ## Traceplot of All Samples

# %%
# Shows the trace with a vertical line at the mean of the trace
def plot_trace(trace):
    # Traceplot with vertical lines at the mean value
    ax = pm.traceplot(trace, figsize=(14, len(trace.varnames)*1.8),
                      lines={k: v['mean'] for k, v in pm.summary(trace).iterrows()})
    
    matplotlib.rcParams['font.size'] = 16
    
    # Labels with the median value
    for i, mn in enumerate(pm.summary(trace)['mean']):
        ax[i, 0].annotate('{:0.2f}'.format(mn), xy = (mn, 0), xycoords = 'data', size = 8,
                          xytext = (-18, 18), textcoords = 'offset points', rotation = 90,
                          va = 'bottom', fontsize = 'large', color = 'red')

# %%
# Print out the mean variable weight from the trace
for variable in normal_trace.varnames:
    print('Variable: {:15} Mean weight in model: {:.4f}'.format(variable, 
                                                                np.mean(normal_trace[variable])))
# Out:
# Variable: Intercept       Mean weight in model: 10.7536
# Variable: V_1             Mean weight in model: -0.0122
# Variable: V_2             Mean weight in model: -0.1244
# Variable: V_3             Mean weight in model: 0.1726
# Variable: V_4             Mean weight in model: -0.2974
# Variable: V_5             Mean weight in model: 0.4016
# Variable: V_6             Mean weight in model: -0.0189
# Variable: V_7             Mean weight in model: -0.4927
# Variable: V_8             Mean weight in model: 0.0329
# Variable: V_9             Mean weight in model: -0.0213
# Variable: V_10            Mean weight in model: -0.1130
# Variable: V_11            Mean weight in model: -0.1151
# Variable: V_12            Mean weight in model: -0.0824
# Variable: V_13            Mean weight in model: 0.0725
# Variable: V_14            Mean weight in model: 0.2194
# Variable: V_15            Mean weight in model: -0.0554
# Variable: V_16            Mean weight in model: -0.0180
# Variable: V_17            Mean weight in model: 0.0083
# Variable: V_18            Mean weight in model: -0.0240
# Variable: V_19            Mean weight in model: -0.0218
# Variable: V_20            Mean weight in model: -0.1969
# Variable: V_21            Mean weight in model: 0.0127
# Variable: V_22            Mean weight in model: 0.1386
# Variable: V_23            Mean weight in model: 0.0364
# Variable: V_24            Mean weight in model: -0.0955
# Variable: V_25            Mean weight in model: -0.0343
# Variable: V_26            Mean weight in model: 0.1860
# Variable: V_27            Mean weight in model: -0.0580
# Variable: V_28            Mean weight in model: 0.0260
# Variable: V_29            Mean weight in model: -0.2030
# Variable: V_30            Mean weight in model: -0.1209
# Variable: V_31            Mean weight in model: 0.1164
# Variable: V_32            Mean weight in model: 0.0708
# Variable: V_33            Mean weight in model: 0.0348
# Variable: V_34            Mean weight in model: -0.0705
# Variable: V_35            Mean weight in model: -0.0083
# Variable: V_36            Mean weight in model: 0.1214
# Variable: V_37            Mean weight in model: -0.0053
# Variable: V_38            Mean weight in model: -0.0139
# Variable: V_39            Mean weight in model: 0.0171
# Variable: V_40            Mean weight in model: 0.0519
# Variable: V_41            Mean weight in model: 0.1084
# Variable: V_42            Mean weight in model: 0.1069
# Variable: V_43            Mean weight in model: -0.0929
# Variable: V_44            Mean weight in model: 0.0110
# Variable: V_45            Mean weight in model: -0.0979
# Variable: V_46            Mean weight in model: 0.1375
# Variable: V_47            Mean weight in model: 0.0603
# Variable: V_48            Mean weight in model: 0.1185
# Variable: V_49            Mean weight in model: -0.0170
# Variable: V_50            Mean weight in model: -0.1273
# Variable: V_51            Mean weight in model: -0.1431
# Variable: V_52            Mean weight in model: -0.0162
# Variable: V_53            Mean weight in model: -0.0052
# Variable: V_54            Mean weight in model: -0.0413
# Variable: V_55            Mean weight in model: 0.1376
# Variable: V_56            Mean weight in model: -0.0729
# Variable: V_57            Mean weight in model: 0.0533
# Variable: V_58            Mean weight in model: 0.0221
# Variable: V_59            Mean weight in model: -0.2054
# Variable: V_60            Mean weight in model: -0.1014
# Variable: V_61            Mean weight in model: 0.0161
# Variable: V_62            Mean weight in model: 0.0004
# Variable: V_63            Mean weight in model: 0.0563
# Variable: V_64            Mean weight in model: 0.1297
# Variable: V_65            Mean weight in model: 0.1617
# Variable: V_66            Mean weight in model: -0.0674
# Variable: V_67            Mean weight in model: 0.0834
# Variable: V_68            Mean weight in model: -0.1529
# Variable: V_69            Mean weight in model: 0.0219
# Variable: V_70            Mean weight in model: -0.0312
# Variable: V_71            Mean weight in model: 0.0412
# Variable: V_72            Mean weight in model: 0.0437
# Variable: V_73            Mean weight in model: -0.0079
# Variable: V_74            Mean weight in model: -0.0870
# Variable: V_75            Mean weight in model: 0.0974
# Variable: V_76            Mean weight in model: -0.0826
# Variable: V_77            Mean weight in model: -0.1622
# Variable: V_78            Mean weight in model: 0.1013
# Variable: V_79            Mean weight in model: -0.0007
# Variable: V_80            Mean weight in model: -0.0027
# Variable: V_81            Mean weight in model: -0.1047
# Variable: V_82            Mean weight in model: 0.0855
# Variable: V_83            Mean weight in model: 0.0164
# Variable: V_84            Mean weight in model: 0.1308
# Variable: V_85            Mean weight in model: -0.2377
# Variable: V_86            Mean weight in model: 0.1496
# Variable: V_87            Mean weight in model: 0.0894
# Variable: V_88            Mean weight in model: -0.1403
# Variable: V_89            Mean weight in model: 0.0810
# Variable: V_90            Mean weight in model: 0.1203
# Variable: V_91            Mean weight in model: 0.1086
# Variable: V_92            Mean weight in model: 0.0745
# Variable: V_93            Mean weight in model: 0.1072
# Variable: V_94            Mean weight in model: -0.1698
# Variable: V_95            Mean weight in model: 0.0002
# Variable: V_96            Mean weight in model: -0.1218
# Variable: V_97            Mean weight in model: 0.1049
# Variable: V_98            Mean weight in model: 0.0371
# Variable: V_99            Mean weight in model: 0.0953
# Variable: V_100           Mean weight in model: -0.0091
# Variable: V_101           Mean weight in model: 0.1681
# Variable: V_102           Mean weight in model: -0.0573
# Variable: V_103           Mean weight in model: -0.0685
# Variable: V_104           Mean weight in model: 0.1321
# Variable: V_105           Mean weight in model: -0.0558
# Variable: V_106           Mean weight in model: 0.0102
# Variable: V_107           Mean weight in model: -0.0805
# Variable: V_108           Mean weight in model: -0.0096
# Variable: V_109           Mean weight in model: 0.0495
# Variable: V_110           Mean weight in model: 0.0779
# Variable: V_111           Mean weight in model: -0.2158
# Variable: V_112           Mean weight in model: 0.0975
# Variable: V_113           Mean weight in model: 0.1258
# Variable: V_114           Mean weight in model: 0.1432
# Variable: V_115           Mean weight in model: -0.0053
# Variable: V_116           Mean weight in model: -0.0453
# Variable: V_117           Mean weight in model: 0.0573
# Variable: V_118           Mean weight in model: -0.1103
# Variable: V_119           Mean weight in model: 0.0595
# Variable: V_120           Mean weight in model: -0.0240
# Variable: V_121           Mean weight in model: 0.0423
# Variable: V_122           Mean weight in model: -0.1240
# Variable: V_123           Mean weight in model: -0.0225
# Variable: V_124           Mean weight in model: 0.0282
# Variable: V_125           Mean weight in model: -0.0007
# Variable: V_126           Mean weight in model: 0.0458
# Variable: V_127           Mean weight in model: -0.1573
# Variable: V_128           Mean weight in model: 0.0149
# Variable: V_129           Mean weight in model: -0.0755
# Variable: V_130           Mean weight in model: -0.0730
# Variable: V_131           Mean weight in model: -0.0129
# Variable: V_132           Mean weight in model: -0.1265
# Variable: V_133           Mean weight in model: -0.0469
# Variable: V_134           Mean weight in model: -0.1647
# Variable: V_135           Mean weight in model: 0.0800
# Variable: V_136           Mean weight in model: 0.0511
# Variable: V_137           Mean weight in model: -0.0403
# Variable: V_138           Mean weight in model: 0.1007
# Variable: V_139           Mean weight in model: 0.0635
# Variable: V_140           Mean weight in model: -0.0012
# Variable: V_141           Mean weight in model: -0.1157
# Variable: V_142           Mean weight in model: -0.0336
# Variable: V_143           Mean weight in model: -0.0297
# Variable: V_144           Mean weight in model: -0.0848
# Variable: V_145           Mean weight in model: 0.0219
# Variable: V_146           Mean weight in model: 0.0578
# Variable: V_147           Mean weight in model: -0.1553
# Variable: V_148           Mean weight in model: 0.2809
# Variable: V_149           Mean weight in model: -0.0300
# Variable: V_150           Mean weight in model: 0.1000
# Variable: V_151           Mean weight in model: -0.0230
# Variable: V_152           Mean weight in model: -0.0838
# Variable: V_153           Mean weight in model: 0.0570
# Variable: V_154           Mean weight in model: -0.0551
# Variable: V_155           Mean weight in model: -0.0115
# Variable: V_156           Mean weight in model: -0.0715
# Variable: V_157           Mean weight in model: 0.0751
# Variable: V_158           Mean weight in model: 0.1384
# Variable: V_159           Mean weight in model: -0.0159
# Variable: V_160           Mean weight in model: 0.0116
# Variable: V_161           Mean weight in model: -0.0260
# Variable: V_162           Mean weight in model: -0.1655
# Variable: V_163           Mean weight in model: -0.0729
# Variable: V_164           Mean weight in model: -0.0526
# Variable: V_165           Mean weight in model: -0.0039
# Variable: V_166           Mean weight in model: -0.0162
# Variable: V_167           Mean weight in model: 0.0221
# Variable: V_168           Mean weight in model: -0.1210
# Variable: V_169           Mean weight in model: -0.1127
# Variable: V_170           Mean weight in model: 0.0403
# Variable: V_171           Mean weight in model: 0.1047
# Variable: V_172           Mean weight in model: -0.1097
# Variable: V_173           Mean weight in model: 0.0544
# Variable: V_174           Mean weight in model: -0.0989
# Variable: V_175           Mean weight in model: -0.0635
# Variable: V_176           Mean weight in model: 0.0996
# Variable: V_177           Mean weight in model: -0.1628
# Variable: V_178           Mean weight in model: 0.0577
# Variable: V_179           Mean weight in model: 0.0535
# Variable: V_180           Mean weight in model: 0.0274
# Variable: V_181           Mean weight in model: -0.0009
# Variable: V_182           Mean weight in model: -0.0889
# Variable: V_183           Mean weight in model: 0.0034
# Variable: V_184           Mean weight in model: 0.0811
# Variable: V_185           Mean weight in model: -0.0571
# Variable: V_186           Mean weight in model: -0.0744
# Variable: V_187           Mean weight in model: -0.0941
# Variable: V_188           Mean weight in model: -0.0041
# Variable: V_189           Mean weight in model: -0.1825
# Variable: V_190           Mean weight in model: -0.1090
# Variable: V_191           Mean weight in model: -0.0371
# Variable: V_192           Mean weight in model: -0.0339
# Variable: V_193           Mean weight in model: 0.0760
# Variable: V_194           Mean weight in model: -0.0958
# Variable: V_195           Mean weight in model: 0.0850
# Variable: V_196           Mean weight in model: 0.1156
# Variable: V_197           Mean weight in model: 0.1112
# Variable: V_198           Mean weight in model: -0.1034
# Variable: V_199           Mean weight in model: 0.0619
# Variable: V_200           Mean weight in model: -0.0864
# Variable: V_201           Mean weight in model: -0.1063
# Variable: V_202           Mean weight in model: -0.0661
# Variable: V_203           Mean weight in model: -0.0770
# Variable: V_204           Mean weight in model: -0.1338
# Variable: V_205           Mean weight in model: 0.0734
# Variable: V_206           Mean weight in model: 0.0711
# Variable: V_207           Mean weight in model: 0.0716
# Variable: V_208           Mean weight in model: 0.0583
# Variable: V_209           Mean weight in model: 0.0671
# Variable: V_210           Mean weight in model: -0.0587
# Variable: V_211           Mean weight in model: 0.0181
# Variable: V_212           Mean weight in model: -0.0193
# Variable: V_213           Mean weight in model: -0.0847
# Variable: V_214           Mean weight in model: -0.1092
# Variable: V_215           Mean weight in model: 0.0700
# Variable: V_216           Mean weight in model: -0.0372
# Variable: V_217           Mean weight in model: 0.0282
# Variable: V_218           Mean weight in model: 0.1272
# Variable: V_219           Mean weight in model: -0.0212
# Variable: V_220           Mean weight in model: 0.0941
# Variable: V_221           Mean weight in model: 0.0904
# Variable: V_222           Mean weight in model: -0.0363
# Variable: V_223           Mean weight in model: 0.0874
# Variable: V_224           Mean weight in model: 0.0719
# Variable: V_225           Mean weight in model: -0.0049
# Variable: V_226           Mean weight in model: -0.0827
# Variable: V_227           Mean weight in model: 0.0396
# Variable: V_228           Mean weight in model: 0.0319
# Variable: V_229           Mean weight in model: 0.0693
# Variable: V_230           Mean weight in model: 0.0112
# Variable: V_231           Mean weight in model: 0.0830
# Variable: V_232           Mean weight in model: 0.0452
# Variable: V_233           Mean weight in model: 0.0278
# Variable: V_234           Mean weight in model: -0.0594
# Variable: V_235           Mean weight in model: -0.0342
# Variable: V_236           Mean weight in model: 0.0869
# Variable: V_237           Mean weight in model: 0.0214
# Variable: V_238           Mean weight in model: 0.0682
# Variable: V_239           Mean weight in model: -0.0087
# Variable: V_240           Mean weight in model: 0.0392
# Variable: V_241           Mean weight in model: 0.1507
# Variable: V_242           Mean weight in model: 0.0413
# Variable: V_243           Mean weight in model: 0.0523
# Variable: V_244           Mean weight in model: 0.0724
# Variable: V_245           Mean weight in model: 0.1252
# Variable: V_246           Mean weight in model: 0.0995
# Variable: V_247           Mean weight in model: 0.0146
# Variable: V_248           Mean weight in model: -0.0846
# Variable: V_249           Mean weight in model: 0.0171
# Variable: V_250           Mean weight in model: -0.0058
# Variable: V_251           Mean weight in model: -0.0789
# Variable: V_252           Mean weight in model: 0.0633
# Variable: V_253           Mean weight in model: -0.0295
# Variable: V_254           Mean weight in model: -0.0651
# Variable: V_255           Mean weight in model: -0.0838
# Variable: V_256           Mean weight in model: 0.1216
# Variable: V_257           Mean weight in model: -0.0615
# Variable: V_258           Mean weight in model: 0.1348
# Variable: V_259           Mean weight in model: 0.0115
# Variable: V_260           Mean weight in model: -0.1483
# Variable: V_261           Mean weight in model: -0.1233
# Variable: V_262           Mean weight in model: -0.0015
# Variable: V_263           Mean weight in model: -0.1138
# Variable: V_264           Mean weight in model: -0.0552
# Variable: V_265           Mean weight in model: -0.1851
# Variable: V_266           Mean weight in model: -0.0965
# Variable: V_267           Mean weight in model: -0.0681
# Variable: V_268           Mean weight in model: 0.0015
# Variable: V_269           Mean weight in model: 0.0263
# Variable: V_270           Mean weight in model: 0.0765
# Variable: V_271           Mean weight in model: -0.0654
# Variable: V_272           Mean weight in model: -0.1277
# Variable: V_273           Mean weight in model: 0.0508
# Variable: V_274           Mean weight in model: 0.0474
# Variable: V_275           Mean weight in model: 0.1009
# Variable: V_276           Mean weight in model: 0.0692
# Variable: V_277           Mean weight in model: 0.1784
# Variable: V_278           Mean weight in model: 0.0948
# Variable: V_279           Mean weight in model: 0.0356
# Variable: V_280           Mean weight in model: -0.0579
# Variable: V_281           Mean weight in model: 0.2153
# Variable: V_282           Mean weight in model: 0.0555
# Variable: V_283           Mean weight in model: 0.0388
# Variable: V_284           Mean weight in model: -0.0039
# Variable: V_285           Mean weight in model: -0.0264
# Variable: V_286           Mean weight in model: 0.0723
# Variable: V_287           Mean weight in model: 0.1240
# Variable: V_288           Mean weight in model: -0.0765
# Variable: V_289           Mean weight in model: 0.1148
# Variable: V_290           Mean weight in model: -0.1991
# Variable: V_291           Mean weight in model: -0.0717
# Variable: V_292           Mean weight in model: -0.0025
# Variable: V_293           Mean weight in model: 0.0522
# Variable: V_294           Mean weight in model: 0.1238
# Variable: V_295           Mean weight in model: -0.0572
# Variable: V_296           Mean weight in model: 0.0939
# Variable: V_297           Mean weight in model: -0.0232
# Variable: V_298           Mean weight in model: -0.0576
# Variable: V_299           Mean weight in model: 0.0896
# Variable: V_300           Mean weight in model: 0.0536
# Variable: V_301           Mean weight in model: 0.0282
# Variable: V_302           Mean weight in model: 0.0052
# Variable: V_303           Mean weight in model: 0.1557
# Variable: V_304           Mean weight in model: -0.0370
# Variable: V_305           Mean weight in model: -0.0371
# Variable: V_306           Mean weight in model: 0.0845
# Variable: V_307           Mean weight in model: -0.0094
# Variable: V_308           Mean weight in model: -0.0559
# Variable: V_309           Mean weight in model: -0.1083
# Variable: V_310           Mean weight in model: -0.2081
# Variable: V_311           Mean weight in model: 0.1104
# Variable: V_312           Mean weight in model: 0.2130
# Variable: V_313           Mean weight in model: 0.0860
# Variable: V_314           Mean weight in model: 0.0200
# Variable: V_315           Mean weight in model: 0.1214
# Variable: V_316           Mean weight in model: 0.1665
# Variable: V_317           Mean weight in model: 0.0784
# Variable: V_318           Mean weight in model: -0.0018
# Variable: V_319           Mean weight in model: -0.1393
# Variable: V_320           Mean weight in model: -0.0513
# Variable: V_321           Mean weight in model: 0.0189
# Variable: V_322           Mean weight in model: 0.0133
# Variable: V_323           Mean weight in model: -0.0926
# Variable: V_324           Mean weight in model: 0.1656
# Variable: V_325           Mean weight in model: 0.1009
# Variable: V_326           Mean weight in model: 0.0903
# Variable: V_327           Mean weight in model: 0.0944
# Variable: V_328           Mean weight in model: 0.1661
# Variable: V_329           Mean weight in model: -0.1836
# Variable: V_330           Mean weight in model: 0.0053
# Variable: V_331           Mean weight in model: -0.0362
# Variable: V_332           Mean weight in model: -0.0026
# Variable: V_333           Mean weight in model: -0.0442
# Variable: V_334           Mean weight in model: -0.0290
# Variable: V_335           Mean weight in model: 0.1002
# Variable: V_336           Mean weight in model: -0.0592
# Variable: V_337           Mean weight in model: -0.0765
# Variable: V_338           Mean weight in model: 0.0285
# Variable: V_339           Mean weight in model: -0.1449
# Variable: V_340           Mean weight in model: -0.0404
# Variable: V_341           Mean weight in model: 0.0104
# Variable: V_342           Mean weight in model: -0.0747
# Variable: V_343           Mean weight in model: 0.0180
# Variable: V_344           Mean weight in model: 0.1294
# Variable: V_345           Mean weight in model: 0.2657
# Variable: V_346           Mean weight in model: -0.0966
# Variable: V_347           Mean weight in model: -0.0534
# Variable: V_348           Mean weight in model: -0.0608
# Variable: V_349           Mean weight in model: 0.0396
# Variable: V_350           Mean weight in model: -0.0928
# Variable: V_351           Mean weight in model: 0.1104
# Variable: V_352           Mean weight in model: -0.2179
# Variable: V_353           Mean weight in model: -0.0720
# Variable: V_354           Mean weight in model: 0.0079
# Variable: V_355           Mean weight in model: 0.0626
# Variable: V_356           Mean weight in model: 0.0749
# Variable: V_357           Mean weight in model: -0.0978
# Variable: V_358           Mean weight in model: -0.0828
# Variable: V_359           Mean weight in model: -0.0042
# Variable: V_360           Mean weight in model: -0.0060
# Variable: V_361           Mean weight in model: 0.1293
# Variable: V_362           Mean weight in model: -0.0194
# Variable: V_363           Mean weight in model: -0.0973
# Variable: V_364           Mean weight in model: -0.0553
# Variable: V_365           Mean weight in model: 0.0629
# Variable: V_366           Mean weight in model: 0.0593
# Variable: V_367           Mean weight in model: -0.1273
# Variable: V_368           Mean weight in model: -0.0004
# Variable: V_369           Mean weight in model: -0.1021
# Variable: V_370           Mean weight in model: 0.0414
# Variable: V_371           Mean weight in model: -0.0259
# Variable: V_372           Mean weight in model: 0.0121
# Variable: V_373           Mean weight in model: 0.0251
# Variable: V_374           Mean weight in model: 0.0132
# Variable: V_375           Mean weight in model: 0.0484
# Variable: V_376           Mean weight in model: 0.0223
# Variable: V_377           Mean weight in model: -0.1652
# Variable: V_378           Mean weight in model: 0.0334
# Variable: V_379           Mean weight in model: 0.0934
# Variable: V_380           Mean weight in model: -0.1463
# Variable: V_381           Mean weight in model: -0.0223
# Variable: V_382           Mean weight in model: 0.0374
# Variable: V_383           Mean weight in model: -0.1537
# Variable: V_384           Mean weight in model: -0.0011
# Variable: V_385           Mean weight in model: 0.0362
# Variable: V_386           Mean weight in model: 0.1080
# Variable: V_387           Mean weight in model: 0.0129
# Variable: V_388           Mean weight in model: 0.0700
# Variable: V_389           Mean weight in model: -0.0633
# Variable: V_390           Mean weight in model: -0.0031
# Variable: V_391           Mean weight in model: 0.1920
# Variable: V_392           Mean weight in model: 0.0797
# Variable: V_393           Mean weight in model: 0.0432
# Variable: V_394           Mean weight in model: 0.0351
# Variable: V_395           Mean weight in model: 0.1264
# Variable: V_396           Mean weight in model: -0.1351
# Variable: V_397           Mean weight in model: -0.1187
# Variable: V_398           Mean weight in model: -0.1810
# Variable: V_399           Mean weight in model: 0.0549
# Variable: V_400           Mean weight in model: -0.0299
# Variable: V_401           Mean weight in model: 0.0248
# Variable: V_402           Mean weight in model: 0.0441
# Variable: V_403           Mean weight in model: -0.1401
# Variable: V_404           Mean weight in model: 0.1002
# Variable: V_405           Mean weight in model: -0.1334
# Variable: V_406           Mean weight in model: 0.1769
# Variable: V_407           Mean weight in model: -0.0128
# Variable: V_408           Mean weight in model: -0.0511
# Variable: V_409           Mean weight in model: -0.0974
# Variable: V_410           Mean weight in model: -0.0453
# Variable: V_411           Mean weight in model: -0.1060
# Variable: V_412           Mean weight in model: 0.0155
# Variable: V_413           Mean weight in model: 0.0094
# Variable: V_414           Mean weight in model: -0.0139
# Variable: V_415           Mean weight in model: -0.1343
# Variable: V_416           Mean weight in model: 0.0172
# Variable: V_417           Mean weight in model: 0.1280
# Variable: V_418           Mean weight in model: -0.1184
# Variable: V_419           Mean weight in model: 0.0477
# Variable: V_420           Mean weight in model: -0.0488
# Variable: V_421           Mean weight in model: 0.0312
# Variable: V_422           Mean weight in model: 0.0626
# Variable: V_423           Mean weight in model: 0.0906
# Variable: V_424           Mean weight in model: -0.0877
# Variable: V_425           Mean weight in model: 0.0057
# Variable: V_426           Mean weight in model: -0.0134
# Variable: V_427           Mean weight in model: 0.0405
# Variable: V_428           Mean weight in model: 0.0044
# Variable: V_429           Mean weight in model: 0.0127
# Variable: V_430           Mean weight in model: 0.0285
# Variable: V_431           Mean weight in model: -0.2342
# Variable: V_432           Mean weight in model: 0.0202
# Variable: V_433           Mean weight in model: 0.0517
# Variable: V_434           Mean weight in model: -0.0601
# Variable: V_435           Mean weight in model: 0.0442
# Variable: V_436           Mean weight in model: -0.0126
# Variable: V_437           Mean weight in model: -0.0890
# Variable: V_438           Mean weight in model: -0.1544
# Variable: V_439           Mean weight in model: -0.1743
# Variable: V_440           Mean weight in model: 0.0142
# Variable: V_441           Mean weight in model: -0.0037
# Variable: V_442           Mean weight in model: -0.0651
# Variable: V_443           Mean weight in model: 0.0533
# Variable: V_444           Mean weight in model: 0.1740
# Variable: V_445           Mean weight in model: -0.0698
# Variable: V_446           Mean weight in model: -0.0762
# Variable: V_447           Mean weight in model: -0.0556
# Variable: V_448           Mean weight in model: -0.0629
# Variable: V_449           Mean weight in model: 0.0548
# Variable: V_450           Mean weight in model: 0.0897
# Variable: V_451           Mean weight in model: 0.3035
# Variable: V_452           Mean weight in model: 0.0408
# Variable: V_453           Mean weight in model: -0.0598
# Variable: V_454           Mean weight in model: 0.0846
# Variable: V_455           Mean weight in model: -0.0571
# Variable: V_456           Mean weight in model: -0.0401
# Variable: V_457           Mean weight in model: 0.0370
# Variable: V_458           Mean weight in model: -0.0176
# Variable: V_459           Mean weight in model: 0.0375
# Variable: V_460           Mean weight in model: 0.1002
# Variable: V_461           Mean weight in model: 0.0051
# Variable: V_462           Mean weight in model: 0.1956
# Variable: V_463           Mean weight in model: 0.0274
# Variable: V_464           Mean weight in model: -0.0484
# Variable: V_465           Mean weight in model: 0.1369
# Variable: V_466           Mean weight in model: -0.0302
# Variable: V_467           Mean weight in model: 0.0176
# Variable: V_468           Mean weight in model: 0.0915
# Variable: V_469           Mean weight in model: -0.1160
# Variable: V_470           Mean weight in model: 0.0085
# Variable: V_471           Mean weight in model: -0.0291
# Variable: V_472           Mean weight in model: -0.0273
# Variable: V_473           Mean weight in model: -0.0199
# Variable: V_474           Mean weight in model: 0.0610
# Variable: V_475           Mean weight in model: 0.2139
# Variable: V_476           Mean weight in model: -0.0458
# Variable: V_477           Mean weight in model: 0.0153
# Variable: V_478           Mean weight in model: -0.0990
# Variable: V_479           Mean weight in model: 0.1737
# Variable: V_480           Mean weight in model: -0.0337
# Variable: V_481           Mean weight in model: 0.1459
# Variable: V_482           Mean weight in model: 0.0249
# Variable: V_483           Mean weight in model: -0.2047
# Variable: V_484           Mean weight in model: 0.0507
# Variable: V_485           Mean weight in model: 0.0935
# Variable: V_486           Mean weight in model: -0.0222
# Variable: V_487           Mean weight in model: -0.0596
# Variable: V_488           Mean weight in model: 0.1365
# Variable: V_489           Mean weight in model: 0.0836
# Variable: V_490           Mean weight in model: -0.1338
# Variable: V_491           Mean weight in model: 0.0835
# Variable: V_492           Mean weight in model: -0.0359
# Variable: V_493           Mean weight in model: -0.1048
# Variable: V_494           Mean weight in model: 0.1126
# Variable: V_495           Mean weight in model: -0.0675
# Variable: V_496           Mean weight in model: 0.0755
# Variable: V_497           Mean weight in model: -0.0939
# Variable: V_498           Mean weight in model: -0.0579
# Variable: V_499           Mean weight in model: 0.0468
# Variable: V_500           Mean weight in model: -0.0409
# Variable: sd_log__        Mean weight in model: 0.9208
# Variable: sd              Mean weight in model: 2.5138

# %% [markdown]
# ### Linear Formula from Bayesian Inference using Mean of Parameters

# %%
model_formula = 'result = '
for variable in normal_trace.varnames:
    model_formula += ' %0.2f * %s +' % (np.mean(normal_trace[variable]), variable)

' '.join(model_formula.split(' ')[:-1])
# Out:
# 'result =  10.75 * Intercept + -0.01 * V_1 + -0.12 * V_2 + 0.17 * V_3 + -0.30 * V_4 + 0.40 * V_5 + -0.02 * V_6 + -0.49 * V_7 + 0.03 * V_8 + -0.02 * V_9 + -0.11 * V_10 + -0.12 * V_11 + -0.08 * V_12 + 0.07 * V_13 + 0.22 * V_14 + -0.06 * V_15 + -0.02 * V_16 + 0.01 * V_17 + -0.02 * V_18 + -0.02 * V_19 + -0.20 * V_20 + 0.01 * V_21 + 0.14 * V_22 + 0.04 * V_23 + -0.10 * V_24 + -0.03 * V_25 + 0.19 * V_26 + -0.06 * V_27 + 0.03 * V_28 + -0.20 * V_29 + -0.12 * V_30 + 0.12 * V_31 + 0.07 * V_32 + 0.03 * V_33 + -0.07 * V_34 + -0.01 * V_35 + 0.12 * V_36 + -0.01 * V_37 + -0.01 * V_38 + 0.02 * V_39 + 0.05 * V_40 + 0.11 * V_41 + 0.11 * V_42 + -0.09 * V_43 + 0.01 * V_44 + -0.10 * V_45 + 0.14 * V_46 + 0.06 * V_47 + 0.12 * V_48 + -0.02 * V_49 + -0.13 * V_50 + -0.14 * V_51 + -0.02 * V_52 + -0.01 * V_53 + -0.04 * V_54 + 0.14 * V_55 + -0.07 * V_56 + 0.05 * V_57 + 0.02 * V_58 + -0.21 * V_59 + -0.10 * V_60 + 0.02 * V_61 + 0.00 * V_62 + 0.06 * V_63 + 0.13 * V_64 + 0.16 * V_65 + -0.07 * V_66 + 0.08 * V_67 + -0.15 * V_68 + 0.02 * V_69 + -0.03 * V_70 + 0.04 * V_71 + 0.04 * V_72 + -0.01 * V_73 + -0.09 * V_74 + 0.10 * V_75 + -0.08 * V_76 + -0.16 * V_77 + 0.10 * V_78 + -0.00 * V_79 + -0.00 * V_80 + -0.10 * V_81 + 0.09 * V_82 + 0.02 * V_83 + 0.13 * V_84 + -0.24 * V_85 + 0.15 * V_86 + 0.09 * V_87 + -0.14 * V_88 + 0.08 * V_89 + 0.12 * V_90 + 0.11 * V_91 + 0.07 * V_92 + 0.11 * V_93 + -0.17 * V_94 + 0.00 * V_95 + -0.12 * V_96 + 0.10 * V_97 + 0.04 * V_98 + 0.10 * V_99 + -0.01 * V_100 + 0.17 * V_101 + -0.06 * V_102 + -0.07 * V_103 + 0.13 * V_104 + -0.06 * V_105 + 0.01 * V_106 + -0.08 * V_107 + -0.01 * V_108 + 0.05 * V_109 + 0.08 * V_110 + -0.22 * V_111 + 0.10 * V_112 + 0.13 * V_113 + 0.14 * V_114 + -0.01 * V_115 + -0.05 * V_116 + 0.06 * V_117 + -0.11 * V_118 + 0.06 * V_119 + -0.02 * V_120 + 0.04 * V_121 + -0.12 * V_122 + -0.02 * V_123 + 0.03 * V_124 + -0.00 * V_125 + 0.05 * V_126 + -0.16 * V_127 + 0.01 * V_128 + -0.08 * V_129 + -0.07 * V_130 + -0.01 * V_131 + -0.13 * V_132 + -0.05 * V_133 + -0.16 * V_134 + 0.08 * V_135 + 0.05 * V_136 + -0.04 * V_137 + 0.10 * V_138 + 0.06 * V_139 + -0.00 * V_140 + -0.12 * V_141 + -0.03 * V_142 + -0.03 * V_143 + -0.08 * V_144 + 0.02 * V_145 + 0.06 * V_146 + -0.16 * V_147 + 0.28 * V_148 + -0.03 * V_149 + 0.10 * V_150 + -0.02 * V_151 + -0.08 * V_152 + 0.06 * V_153 + -0.06 * V_154 + -0.01 * V_155 + -0.07 * V_156 + 0.08 * V_157 + 0.14 * V_158 + -0.02 * V_159 + 0.01 * V_160 + -0.03 * V_161 + -0.17 * V_162 + -0.07 * V_163 + -0.05 * V_164 + -0.00 * V_165 + -0.02 * V_166 + 0.02 * V_167 + -0.12 * V_168 + -0.11 * V_169 + 0.04 * V_170 + 0.10 * V_171 + -0.11 * V_172 + 0.05 * V_173 + -0.10 * V_174 + -0.06 * V_175 + 0.10 * V_176 + -0.16 * V_177 + 0.06 * V_178 + 0.05 * V_179 + 0.03 * V_180 + -0.00 * V_181 + -0.09 * V_182 + 0.00 * V_183 + 0.08 * V_184 + -0.06 * V_185 + -0.07 * V_186 + -0.09 * V_187 + -0.00 * V_188 + -0.18 * V_189 + -0.11 * V_190 + -0.04 * V_191 + -0.03 * V_192 + 0.08 * V_193 + -0.10 * V_194 + 0.09 * V_195 + 0.12 * V_196 + 0.11 * V_197 + -0.10 * V_198 + 0.06 * V_199 + -0.09 * V_200 + -0.11 * V_201 + -0.07 * V_202 + -0.08 * V_203 + -0.13 * V_204 + 0.07 * V_205 + 0.07 * V_206 + 0.07 * V_207 + 0.06 * V_208 + 0.07 * V_209 + -0.06 * V_210 + 0.02 * V_211 + -0.02 * V_212 + -0.08 * V_213 + -0.11 * V_214 + 0.07 * V_215 + -0.04 * V_216 + 0.03 * V_217 + 0.13 * V_218 + -0.02 * V_219 + 0.09 * V_220 + 0.09 * V_221 + -0.04 * V_222 + 0.09 * V_223 + 0.07 * V_224 + -0.00 * V_225 + -0.08 * V_226 + 0.04 * V_227 + 0.03 * V_228 + 0.07 * V_229 + 0.01 * V_230 + 0.08 * V_231 + 0.05 * V_232 + 0.03 * V_233 + -0.06 * V_234 + -0.03 * V_235 + 0.09 * V_236 + 0.02 * V_237 + 0.07 * V_238 + -0.01 * V_239 + 0.04 * V_240 + 0.15 * V_241 + 0.04 * V_242 + 0.05 * V_243 + 0.07 * V_244 + 0.13 * V_245 + 0.10 * V_246 + 0.01 * V_247 + -0.08 * V_248 + 0.02 * V_249 + -0.01 * V_250 + -0.08 * V_251 + 0.06 * V_252 + -0.03 * V_253 + -0.07 * V_254 + -0.08 * V_255 + 0.12 * V_256 + -0.06 * V_257 + 0.13 * V_258 + 0.01 * V_259 + -0.15 * V_260 + -0.12 * V_261 + -0.00 * V_262 + -0.11 * V_263 ...

# %%
X_test.columns[:500]
# Out:
# Index(['V_1', 'V_2', 'V_3', 'V_4', 'V_5', 'V_6', 'V_7', 'V_8', 'V_9', 'V_10',
#        ...
#        'V_491', 'V_492', 'V_493', 'V_494', 'V_495', 'V_496', 'V_497', 'V_498',
#        'V_499', 'V_500'],
#       dtype='object', length=500)

# %% [markdown]
# ## Evaluate Bayesian Model Using Mean of Model Parameters

# %%
# Evalute the MCMC trace and compare to ml models
def evaluate_trace(trace, X_train, X_test, y_train, y_test, model_results):
    
    # Dictionary of all sampled values for each parameter
    var_dict = {}
    for variable in trace.varnames:
        var_dict[variable] = trace[variable]
        
    # Results into a dataframe
    var_weights = pd.DataFrame(var_dict)
    
    # Means for all the weights
    var_means = var_weights.mean(axis=0)
    
    # Create an intercept column
    X_test['Intercept'] = 1
    
    # Align names of the test observations and means
    names = X_test.columns[:1000]
    X_test = X_test.loc[:, names]
    var_means = var_means[names]
    
    # Calculate estimate for each test observation using the average weights
    results = pd.DataFrame(index = X_test.index, columns = ['estimate'])

    for row in X_test.iterrows():
        results.loc[row[0], 'estimate'] = np.dot(np.array(var_means), np.array(row[1]))
        
    # Metrics 
    actual = np.array(y_test)
    errors = results['estimate'] - actual
    mae = np.mean(abs(errors))
    rmse = np.sqrt(np.mean(errors ** 2))
    
    print('Model  MAE: {:.4f}\nModel RMSE: {:.4f}'.format(mae, rmse))
    
    # Add the results to the comparison dataframe
    model_results.loc['Bayesian LR', :] = [mae, rmse]
    
    plt.figure(figsize=(12, 8))
    
    # Plot median absolute percentage error of all models
    ax = plt.subplot(1, 2, 1)
    model_results.sort_values('mae', ascending = True).plot.bar(y = 'mae', color = 'r', ax = ax)
    plt.title('Model Mean Absolute Error Comparison'); plt.ylabel('MAE'); 
    plt.tight_layout()
    
    # Plot root mean squared error of all models
    ax = plt.subplot(1, 2, 2)
    model_results.sort_values('rmse', ascending = True).plot.bar(y = 'rmse', color = 'b', ax = ax)
    plt.title('Model RMSE Comparison'); plt.ylabel('RMSE')
    
    return model_results

# %%
all_model_results = evaluate_trace(normal_trace, X_train, X_test, y_train, y_test, results)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# Model  MAE: nan
# Model RMSE: nan

# %%
all_model_results
# Out:
#                            mae     rmse
# Linear Regression      4.47886  6.04749
# ElasticNet Regression   2.3466  3.08015
# Random Forest          2.64684  3.42069
# Extra Trees            2.70341  3.51077
# SVM                    3.03147  3.95849
# Gradient Boosted       2.57864  3.34701
# Baseline               3.12653  4.06305
# Bayesian LR                NaN      NaN

# %% [markdown]
# # Make Predictions from Model

# %% [markdown]
# ## Test Observations

# %%
# Make a new prediction from the test set and compare to actual value
def test_model(trace, test_observation):
    
    # Print out the test observation data
    print('Test Observation:')
    print(test_observation)
    var_dict = {}
    for variable in trace.varnames:
        var_dict[variable] = trace[variable]

    # Results into a dataframe
    var_weights = pd.DataFrame(var_dict)
    
    # Standard deviation of the likelihood
    sd_value = var_weights['sd'].mean()

    # Actual Value
    actual = test_observation['B1']
    
    # Add in intercept term
    test_observation['Intercept'] = 1
    test_observation = test_observation.drop('B1')
    
    # Align weights and test observation
    var_weights = var_weights[test_observation.index]

    # Means for all the weights
    var_means = var_weights.mean(axis=0)

    # Location of mean for observation
    mean_loc = np.dot(var_means, test_observation)
    
    # Estimates of grade
    estimates = np.random.normal(loc = mean_loc, scale = sd_value,
                                 size = 1000)

    # Plot all the estimates
    plt.figure(figsize(8, 8))
    sns.distplot(estimates, hist = True, kde = True, bins = 19,
                 hist_kws = {'edgecolor': 'k', 'color': 'darkblue'},
                kde_kws = {'linewidth' : 4},
                label = 'Estimated Dist.')
    # Plot the actual grade
    plt.vlines(x = actual, ymin = 0, ymax = 5, 
               linestyles = '--', colors = 'red',
               label = 'True Result',
              linewidth = 2.5)
    
    # Plot the mean estimate
    plt.vlines(x = mean_loc, ymin = 0, ymax = 5, 
               linestyles = '-', colors = 'orange',
               label = 'Mean Estimate',
              linewidth = 2.5)
    
    plt.legend(loc = 1)
    plt.title('Density Plot for Test Observation');
    plt.xlabel('B1'); plt.ylabel('Density');
    
    # Prediction information
    print('True Result = %d' % actual)
    print('Average Estimate = %0.4f' % mean_loc)
    print('5%% Estimate = %0.4f    95%% Estimate = %0.4f' % (np.percentile(estimates, 5),
                                       np.percentile(estimates, 95)))

# %%
# Make a new prediction from the test set and compare to actual value
def ogi_model(trace, test_observation):
    
    # Print out the test observation data
    var_dict = {}
    for variable in trace.varnames:
        var_dict[variable] = trace[variable]

    # Results into a dataframe
    var_weights = pd.DataFrame(var_dict)
    
    # Standard deviation of the likelihood
    sd_value = var_weights['sd'].mean()

    # Actual Value
    actual = test_observation['B1']
    
    # Add in intercept term
    test_observation['Intercept'] = 1
    test_observation = test_observation.drop('B1')
    
    # Align weights and test observation
    var_weights = var_weights[test_observation.index]

    # Means for all the weights
    var_means = var_weights.mean(axis=0)

    # Location of mean for observation
    mean_loc = np.dot(var_means, test_observation)
    
    # Estimates of grade
    estimates = np.random.normal(loc = mean_loc, scale = sd_value,
                                 size = 1000)
    
    #correlation
    #ogi_corr = np.corrcoef(actual,mean_loc)
    
    # Prediction information
    print('True Result = %0.4f' % actual)
    print('Average Estimate = %0.4f' % mean_loc)
    print('5%% Estimate = %0.4f    95%% Estimate = %0.4f' % (np.percentile(estimates, 5),
                                       np.percentile(estimates, 95)))
    return result.append(mean_loc), true_result.append(actual);

# %%
result=[]
true_result=[]

# %%
X_test
# Out:
#            V_1        V_2       V_3       V_4       V_5       V_6       V_7  \
# 521  16.103523 -18.012638  1.774517  0.231806 -1.202314  1.687142 -1.171032
# 737  56.159618  -3.486274 -5.174526  0.324878 -1.188367 -1.149632  0.012646
# 740  37.026199   0.143746 -4.144331 -1.368631  1.362436 -0.856547 -2.690022
# 660  67.783585  -5.306079 -7.665409  5.109962  2.457887 -4.223122  1.308179
# 411 -17.415921  -4.695930  0.369846  4.387326  0.960021 -0.134210 -2.256521
# ..         ...        ...       ...       ...       ...       ...       ...
# 109  11.984640   9.672818  3.299921  0.162544  0.708303 -1.578853  0.389079
# 430 -40.018183   3.165388  2.555651  1.285790 -4.223451 -1.786444  1.112726
# 77  -23.850513   1.280066 -3.688450 -1.678385 -2.280238 -1.767957  0.067850
# 84  -29.033503  -3.311687  2.423343 -1.394773  1.040692  1.273193  1.352422
# 286 -29.662701  -7.923200 -3.032548  2.929804 -1.739976 -0.358251  0.924367
#
#           V_8       V_9      V_10  ...     V_493     V_494     V_495  \
# 521  0.845837 -1.038925 -1.225543  ...  0.411148 -0.593112  1.155714
# 737  0.463927  0.957142  0.990513  ...  0.618322 -1.978408 -0.676340
# 740 -0.136222  1.917291 -0.510193  ... -0.801954  1.095741  1.758647
# 660  2.635992 -1.743040  2.630558  ...  0.082499 -0.132709  0.036466
# 411  1.930638  0.277730  0.137109  ... -1.624745  0.604763 -0.907887
# ..        ...       ...       ...  ...       ...       ...       ...
# 109  1.257730  2.066421  3.154650  ...  3.664629 -1.351239 -0.368284
# 430 -0.506646  0.220790 -1.530040  ...  0.034034  1.287103 -1.595475
# 77  -2.406675 -3.190294 -0.347705  ... -1.350421  1.385420  0.763429
# 84   1.536492 -0.730475  0.338430  ... -0.899488  0.033309  0.536763
# 286 -0.224554  1.090342 -1.110474  ...  0.617043 -1.312699 -0.525142
#
#         V_496     V_497     V_498     V_499     V_500         B1  Intercept
# 521 -2.353344  1.295046 -1.683937 -1.706324  0.612207  12.456493          1
# 737  1.319618  0.789316  1.533342  1.426829 -0.318287   8.103241          1
# 740 -0.359475  1.185891 -0.974809  1.314078  0.231410  11.900554          1
# 660  0.288367  0.118371 -1.482942  3.275546 -1.520645   5.037638          1
# 411  2.715713 -0.466927  0.374117 -1.350780 -1.271868  10.286819          1
# ..        ...       ...       ...       ...       ...        ...        ...
# 109  1.635066  0.881964 -0.376960 -2.154344  1.008260   9.707505          1
# 430 -2.217601  1.453442 -1.646384  0.561842  2.056868   4.715527          1
# 77  -0.528749  2.412863  0.421397  1.958365  1.413429  12.265376          1
# 84   1.656798  0.513124  1.740634 -2.653938 -0.280218   6.911504          1
# 286  2.385019  1.305106 -0.499696  0.614563  0.561197   5.357608          1
#
# [250 rows x 502 columns]

# %%
i = 1
while i >= 0 :
    ogi_model(normal_trace, X_test.iloc[i])
    i = i + 1
    if i == 250:
        break
print(true_result)
print(result)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# True Result = 8.1032
# Average Estimate = 9.8566
# 5% Estimate = 5.6280    95% Estimate = 13.9816
# True Result = 11.9006
# Average Estimate = 22.5185
# 5% Estimate = 18.4792    95% Estimate = 26.1142
# True Result = 5.0376
# Average Estimate = -3.1422
# 5% Estimate = -7.7413    95% Estimate = 0.9620
# True Result = 10.2868
# Average Estimate = 8.3790
# 5% Estimate = 4.5331    95% Estimate = 12.7101
# True Result = 11.1649
# Average Estimate = 8.3407
# 5% Estimate = 4.0619    95% Estimate = 12.5810
# True Result = 12.6209
# Average Estimate = 11.7831
# 5% Estimate = 7.7357    95% Estimate = 15.8836
# True Result = 6.8283
# Average Estimate = 8.2740
# 5% Estimate = 4.0259    95% Estimate = 12.1350
# True Result = 9.5544
# Average Estimate = 19.3801
# 5% Estimate = 15.4385    95% Estimate = 23.7218
# True Result = 15.8900
# Average Estimate = 21.2186
# 5% Estimate = 17.0560    95% Estimate = 25.5144
# True Result = 10.8969
# Average Estimate = -5.2749
# 5% Estimate = -9.3711    95% Estimate = -1.1677
# True Result = 11.6074
# Average Estimate = 10.1144
# 5% Estimate = 6.2350    95% Estimate = 14.3226
# True Result = 10.4298
# Average Estimate = 20.1145
# 5% Estimate = 16.1244    95% Estimate = 23.7807
# True Result = 7.6604
# Average Estimate = 16.0547
# 5% Estimate = 11.9407    95% Estimate = 20.0940
# True Result = 8.0993
# Average Estimate = 7.0055
# 5% Estimate = 2.7396    95% Estimate = 11.3238
# True Result = 6.1547
# Average Estimate = 6.7911
# 5% Estimate = 2.7044    95% Estimate = 10.6793
# True Result = 13.6853
# Average Estimate = 2.0523
# 5% Estimate = -1.9871    95% Estimate = 6.0747
# True Result = 10.6140
# Average Estimate = -5.2410
# 5% Estimate = -9.1958    95% Estimate = -1.1293
# True Result = 12.7163
# Average Estimate = 15.4758
# 5% Estimate = 11.0717    95% Estimate = 19.4576
# True Result = 13.9609
# Average Estimate = 12.1930
# 5% Estimate = 8.2420    95% Estimate = 16.1865
# True Result = 19.0521
# Average Estimate = 16.8875
# 5% Estimate = 12.4717    95% Estimate = 20.8955
# True Result = 5.2900
# Average Estimate = 8.6674
# 5% Estimate = 4.2350    95% Estimate = 12.6195
# True Result = 11.9234
# Average Estimate = 12.2084
# 5% Estimate = 8.0119    95% Estimate = 16.4410
# True Result = 12.4455
# Average Estimate = 15.9654
# 5% Estimate = 11.6339    95% Estimate = 19.8741
# True Result = 12.6051
# Average Estimate = 10.8397
# 5% Estimate = 6.7436    95% Estimate = 14.9068
# True Result = 9.5828
# Average Estimate = 14.6025
# 5% Estimate = 10.4871    95% Estimate = 18.6586
# True Result = 13.8542
# Average Estimate = 10.7925
# 5% Estimate = 6.6791    95% Estimate = 14.8324
# True Result = 8.1559
# Average Estimate = -6.0353
# 5% Estimate = -10.3969    95% Estimate = -1.9608
# True Result = 15.0794
# Average Estimate = 11.4736
# 5% Estimate = 7.4220    95% Estimate = 15.4939
# True Result = 14.4686
# Average Estimate = 9.0495
# 5% Estimate = 5.2795    95% Estimate = 13.2417
# True Result = 8.5933
# Average Estimate = 6.6784
# 5% Estimate = 2.6943    95% Estimate = 10.7262
# True Result = 9.7506
# Average Estimate = 10.2513
# 5% Estimate = 6.5730    95% Estimate = 14.3066
# True Result = 13.7368
# Average Estimate = 24.4715
# 5% Estimate = 20.3976    95% Estimate = 28.4493
# True Result = 10.1269
# Average Estimate = 9.6876
# 5% Estimate = 5.5718    95% Estimate = 13.7555
# True Result = 14.4184
# Average Estimate = 11.4882
# 5% Estimate = 7.2673    95% Estimate = 15.3404
# True Result = 18.0347
# Average Estimate = 13.0077
# 5% Estimate = 8.8057    95% Estimate = 17.1380
# True Result = 22.9539
# Average Estimate = 25.8243
# 5% Estimate = 21.8230    95% Estimate = 29.9363
# True Result = 9.4804
# Average Estimate = 14.7161
# 5% Estimate = 10.5322    95% Estimate = 18.8481
# True Result = 18.8127
# Average Estimate = 23.4988
# 5% Estimate = 19.2963    95% Estimate = 27.5929
# True Result = 13.0716
# Average Estimate = 5.0171
# 5% Estimate = 0.7942    95% Estimate = 9.2170
# True Result = 7.3052
# Average Estimate = 7.6416
# 5% Estimate = 3.6247    95% Estimate = 11.8899
# True Result = 12.3531
# Average Estimate = 13.2678
# 5% Estimate = 9.0042    95% Estimate = 17.0731
# True Result = 11.1486
# Average Estimate = 12.4028
# 5% Estimate = 8.1788    95% Estimate = 16.3927
# True Result = 10.5564
# Average Estimate = 11.3356
# 5% Estimate = 7.0840    95% Estimate = 15.5930
# True Result = 11.7921
# Average Estimate = 12.0516
# 5% Estimate = 8.0297    95% Estimate = 15.9770
# True Result = 15.5922
# Average Estimate = 14.7934
# 5% Estimate = 10.7663    95% Estimate = 18.9321
# True Result = 12.3895
# Average Estimate = 10.8581
# 5% Estimate = 6.6837    95% Estimate = 14.5125
# True Result = 9.3818
# Average Estimate = 19.2452
# 5% Estimate = 15.0508    95% Estimate = 23.4042
# True Result = 11.3840
# Average Estimate = 13.3801
# 5% Estimate = 9.2514    95% Estimate = 17.5683
# True Result = 8.8620
# Average Estimate = 14.2709
# 5% Estimate = 10.0714    95% Estimate = 18.3624
# True Result = 15.3448
# Average Estimate = 12.0181
# 5% Estimate = 7.7270    95% Estimate = 15.9892
# True Result = 15.0883
# Average Estimate = 9.5343
# 5% Estimate = 5.6625    95% Estimate = 13.8132
# True Result = 8.8302
# Average Estimate = 12.1661
# 5% Estimate = 7.8501    95% Estimate = 16.3383
# True Result = 15.0819
# Average Estimate = 8.1081
# 5% Estimate = 4.0389    95% Estimate = 12.2895
# True Result = 8.5637
# Average Estimate = 12.9049
# 5% Estimate = 8.7500    95% Estimate = 17.0060
# True Result = 7.8679
# Average Estimate = 13.4346
# 5% Estimate = 9.2784    95% Estimate = 17.9290
# True Result = 11.8142
# Average Estimate = 7.1612
# 5% Estimate = 3.2159    95% Estimate = 11.4352
# True Result = 19.3177
# Average Estimate = 13.7360
# 5% Estimate = 9.7716    95% Estimate = 17.7826
# True Result = 6.6390
# Average Estimate = 12.1789
# 5% Estimate = 7.9484    95% Estimate = 16.3741
# True Result = 4.0785
# Average Estimate = -3.0365
# 5% Estimate = -7.1805    95% Estimate = 0.9286
# True Result = 7.4361
# Average Estimate = 10.3861
# 5% Estimate = 6.1222    95% Estimate = 14.4476
# True Result = 11.6577
# Average Estimate = 9.5464
# 5% Estimate = 5.4400    95% Estimate = 13.8619
# True Result = 16.8332
# Average Estimate = 17.3978
# 5% Estimate = 13.2957    95% Estimate = 21.5361
# True Result = 20.0915
# Average Estimate = 13.4668
# 5% Estimate = 9.0177    95% Estimate = 17.5480
# True Result = 6.2113
# Average Estimate = 5.8224
# 5% Estimate = 1.5461    95% Estimate = 10.2005
# True Result = 5.5403
# Average Estimate = -3.5204
# 5% Estimate = -7.9886    95% Estimate = 0.6989
# True Result = 6.9641
# Average Estimate = 3.8420
# 5% Estimate = -0.2855    95% Estimate = 7.7433
# True Result = 7.0983
# Average Estimate = 17.4156
# 5% Estimate = 13.2560    95% Estimate = 21.6486
# True Result = 11.5476
# Average Estimate = 9.9252
# 5% Estimate = 5.5874    95% Estimate = 13.9433
# True Result = 12.9182
# Average Estimate = 13.7103
# 5% Estimate = 9.5367    95% Estimate = 17.8881
# True Result = 14.6624
# Average Estimate = 7.1099
# 5% Estimate = 3.0134    95% Estimate = 11.2242
# True Result = 7.7484
# Average Estimate = 10.4799
# 5% Estimate = 6.2398    95% Estimate = 14.7935
# True Result = 4.3821
# Average Estimate = 5.8700
# 5% Estimate = 1.5228    95% Estimate = 9.6709
# True Result = 8.0832
# Average Estimate = 0.2206
# 5% Estimate = -3.9691    95% Estimate = 4.2697
# True Result = 7.3642
# Average Estimate = 9.4039
# 5% Estimate = 5.1303    95% Estimate = 13.9633
# True Result = 16.0072
# Average Estimate = 8.4041
# 5% Estimate = 4.2091    95% Estimate = 12.4896
# True Result = 7.3947
# Average Estimate = 9.1332
# 5% Estimate = 5.1142    95% Estimate = 12.9240
# True Result = 12.2930
# Average Estimate = 17.3230
# 5% Estimate = 13.4833    95% Estimate = 21.4114
# True Result = 5.1957
# Average Estimate = 6.4936
# 5% Estimate = 2.3825    95% Estimate = 10.6338
# True Result = 15.1027
# Average Estimate = 13.1949
# 5% Estimate = 9.0668    95% Estimate = 17.1900
# True Result = 17.8973
# Average Estimate = 15.5562
# 5% Estimate = 11.4423    95% Estimate = 19.5132
# True Result = 9.7200
# Average Estimate = 16.4276
# 5% Estimate = 12.4213    95% Estimate = 20.7130
# True Result = 7.9118
# Average Estimate = 1.3264
# 5% Estimate = -3.0224    95% Estimate = 5.1402
# True Result = 13.9915
# Average Estimate = 21.2574
# 5% Estimate = 17.1153    95% Estimate = 25.3447
# True Result = 10.7992
# Average Estimate = 10.9973
# 5% Estimate = 7.1278    95% Estimate = 15.5296
# True Result = 14.5131
# Average Estimate = 16.7412
# 5% Estimate = 12.5244    95% Estimate = 20.7444
# True Result = 7.0409
# Average Estimate = 6.7726
# 5% Estimate = 2.2608    95% Estimate = 11.0915
# True Result = 17.0326
# Average Estimate = 16.4772
# 5% Estimate = 12.3682    95% Estimate = 21.0136
# True Result = 9.9543
# Average Estimate = 10.4520
# 5% Estimate = 6.3051    95% Estimate = 14.5549
# True Result = 9.3796
# Average Estimate = 6.6305
# 5% Estimate = 2.5262    95% Estimate = 10.7434
# True Result = 11.0570
# Average Estimate = 12.5422
# 5% Estimate = 8.6835    95% Estimate = 16.5303
# True Result = 11.3691
# Average Estimate = 12.9076
# 5% Estimate = 8.4891    95% Estimate = 17.0195
# True Result = 11.9272
# Average Estimate = 9.6696
# 5% Estimate = 5.5618    95% Estimate = 13.9405
# True Result = 11.0308
# Average Estimate = 12.1786
# 5% Estimate = 8.0135    95% Estimate = 16.2442
# True Result = 5.8148
# Average Estimate = 0.1284
# 5% Estimate = -4.0088    95% Estimate = 4.4266
# True Result = 12.8611
# Average Estimate = 11.7450
# 5% Estimate = 7.6907    95% Estimate = 15.8410
# True Result = 10.2242
# Average Estimate = 5.3753
# 5% Estimate = 1.3589    95% Estimate = 9.5432
# True Result = 7.9668
# Average Estimate = 11.6478
# 5% Estimate = 7.4008    95% Estimate = 15.8904
# True Result = 6.1823
# Average Estimate = 9.0639
# 5% Estimate = 5.3411    95% Estimate = 13.1309
# True Result = 4.5485
# Average Estimate = -2.9114
# 5% Estimate = -7.3336    95% Estimate = 1.6030
# True Result = 9.9504
# Average Estimate = 4.5361
# 5% Estimate = 0.1765    95% Estimate = 8.6727
# True Result = 7.1042
# Average Estimate = 9.5803
# 5% Estimate = 5.2731    95% Estimate = 13.6773
# True Result = 14.1307
# Average Estimate = 7.4205
# 5% Estimate = 3.3770    95% Estimate = 11.6857
# True Result = 14.4873
# Average Estimate = 11.3699
# 5% Estimate = 7.6209    95% Estimate = 15.7029
# True Result = 15.5406
# Average Estimate = 12.2896
# 5% Estimate = 8.2910    95% Estimate = 16.3614
# True Result = 9.6077
# Average Estimate = 12.1544
# 5% Estimate = 8.1879    95% Estimate = 16.3012
# True Result = 11.3953
# Average Estimate = 13.2491
# 5% Estimate = 9.0292    95% Estimate = 16.9326
# True Result = 8.1705
# Average Estimate = 0.1010
# 5% Estimate = -4.2821    95% Estimate = 4.4499
# True Result = 9.3981
# Average Estimate = 6.8085
# 5% Estimate = 2.6080    95% Estimate = 10.8746
# True Result = 8.2940
# Average Estimate = 12.1228
# 5% Estimate = 7.8126    95% Estimate = 16.5118
# True Result = 7.8273
# Average Estimate = 7.0600
# 5% Estimate = 2.9737    95% Estimate = 11.2835
# True Result = 10.6024
# Average Estimate = 14.8912
# 5% Estimate = 10.8706    95% Estimate = 19.0181
# True Result = 4.7774
# Average Estimate = 14.2915
# 5% Estimate = 10.0961    95% Estimate = 18.4204
# True Result = 8.7511
# Average Estimate = 5.4547
# 5% Estimate = 1.5528    95% Estimate = 9.8074
# True Result = 3.5761
# Average Estimate = 3.1752
# 5% Estimate = -0.9830    95% Estimate = 7.3321
# True Result = 7.8139
# Average Estimate = 14.9671
# 5% Estimate = 10.9232    95% Estimate = 18.9259
# True Result = 16.2700
# Average Estimate = 17.9490
# 5% Estimate = 13.9379    95% Estimate = 21.8870
# True Result = 15.6077
# Average Estimate = 27.5965
# 5% Estimate = 23.2057    95% Estimate = 31.6091
# True Result = 14.9861
# Average Estimate = 14.0959
# 5% Estimate = 10.0261    95% Estimate = 18.3016
# True Result = 9.4271
# Average Estimate = 13.8032
# 5% Estimate = 9.7723    95% Estimate = 17.9326
# True Result = 12.8984
# Average Estimate = 11.6780
# 5% Estimate = 7.6037    95% Estimate = 15.4404
# True Result = 15.4664
# Average Estimate = 16.7475
# 5% Estimate = 12.3702    95% Estimate = 20.9477
# True Result = 16.4015
# Average Estimate = 17.9531
# 5% Estimate = 13.6401    95% Estimate = 21.9690
# True Result = 13.9524
# Average Estimate = 11.7036
# 5% Estimate = 7.4995    95% Estimate = 15.8285
# True Result = 13.8106
# Average Estimate = 18.5751
# 5% Estimate = 14.2559    95% Estimate = 22.3404
# True Result = 10.5934
# Average Estimate = 20.4338
# 5% Estimate = 16.3685    95% Estimate = 24.8364
# True Result = 11.2147
# Average Estimate = 10.3351
# 5% Estimate = 6.2341    95% Estimate = 14.3389
# True Result = 9.9269
# Average Estimate = 7.2847
# 5% Estimate = 3.1932    95% Estimate = 11.5647
# True Result = 5.6000
# Average Estimate = -6.5695
# 5% Estimate = -10.8425    95% Estimate = -2.5176
# True Result = 12.8164
# Average Estimate = 12.2188
# 5% Estimate = 7.9439    95% Estimate = 16.3148
# True Result = 16.1267
# Average Estimate = 16.8008
# 5% Estimate = 12.8805    95% Estimate = 21.2575
# True Result = 13.0004
# Average Estimate = 5.3436
# 5% Estimate = 1.2959    95% Estimate = 9.3632
# True Result = 12.9828
# Average Estimate = 13.7634
# 5% Estimate = 9.5511    95% Estimate = 17.8482
# True Result = 6.0774
# Average Estimate = 15.8332
# 5% Estimate = 11.9995    95% Estimate = 19.9307
# True Result = 10.8810
# Average Estimate = 7.8424
# 5% Estimate = 3.7295    95% Estimate = 11.8044
# True Result = 8.9096
# Average Estimate = -3.4166
# 5% Estimate = -7.5468    95% Estimate = 0.5939
# True Result = 7.3604
# Average Estimate = 11.5875
# 5% Estimate = 7.4705    95% Estimate = 15.7072
# True Result = 5.3087
# Average Estimate = -3.3655
# 5% Estimate = -7.5837    95% Estimate = 0.6074
# True Result = 11.0612
# Average Estimate = 13.7815
# 5% Estimate = 9.7771    95% Estimate = 17.8754
# True Result = 9.9017
# Average Estimate = 7.8796
# 5% Estimate = 3.6081    95% Estimate = 12.3537
# True Result = 7.9857
# Average Estimate = 11.3503
# 5% Estimate = 7.1322    95% Estimate = 15.6190
# True Result = 7.7094
# Average Estimate = 0.6805
# 5% Estimate = -3.3607    95% Estimate = 4.7702
# True Result = 5.6037
# Average Estimate = 2.2298
# 5% Estimate = -1.8050    95% Estimate = 6.2806
# True Result = 10.0393
# Average Estimate = 10.8445
# 5% Estimate = 6.9488    95% Estimate = 15.1729
# True Result = 10.0046
# Average Estimate = 36.3517
# 5% Estimate = 32.4763    95% Estimate = 40.3310
# True Result = 8.0003
# Average Estimate = 1.0928
# 5% Estimate = -3.0045    95% Estimate = 5.5314
# True Result = 11.8322
# Average Estimate = 5.3825
# 5% Estimate = 1.1155    95% Estimate = 9.0565
# True Result = 6.7252
# Average Estimate = 10.4835
# 5% Estimate = 6.5661    95% Estimate = 14.7049
# True Result = 8.8743
# Average Estimate = 4.4791
# 5% Estimate = 0.3448    95% Estimate = 8.8085
# True Result = 14.7636
# Average Estimate = 14.6740
# 5% Estimate = 10.6327    95% Estimate = 18.7270
# True Result = 7.2035
# Average Estimate = 12.6258
# 5% Estimate = 8.5899    95% Estimate = 16.5626
# True Result = 4.5840
# Average Estimate = 20.0070
# 5% Estimate = 15.9229    95% Estimate = 24.0611
# True Result = 10.1679
# Average Estimate = 2.7493
# 5% Estimate = -1.4472    95% Estimate = 6.8018
# True Result = 24.0649
# Average Estimate = 21.5888
# 5% Estimate = 17.6709    95% Estimate = 25.8648
# True Result = 7.6816
# Average Estimate = 21.3556
# 5% Estimate = 17.1331    95% Estimate = 25.6354
# True Result = 18.9784
# Average Estimate = 14.1209
# 5% Estimate = 9.9662    95% Estimate = 18.2842
# True Result = 7.6005
# Average Estimate = 12.1507
# 5% Estimate = 7.7573    95% Estimate = 16.1193
# True Result = 7.9119
# Average Estimate = -7.4675
# 5% Estimate = -11.6902    95% Estimate = -3.3036
# True Result = 8.5903
# Average Estimate = 2.7100
# 5% Estimate = -1.5469    95% Estimate = 6.8298
# True Result = 15.0927
# Average Estimate = 13.2491
# 5% Estimate = 8.9169    95% Estimate = 17.4436
# True Result = 10.3357
# Average Estimate = 16.7183
# 5% Estimate = 12.6193    95% Estimate = 20.6966
# True Result = 13.1634
# Average Estimate = 20.1239
# 5% Estimate = 16.2749    95% Estimate = 24.4717
# True Result = 5.2514
# Average Estimate = 0.6028
# 5% Estimate = -3.5059    95% Estimate = 4.8169
# True Result = 8.7255
# Average Estimate = 5.6775
# 5% Estimate = 1.5570    95% Estimate = 9.9902
# True Result = 7.8049
# Average Estimate = 6.3146
# 5% Estimate = 2.2366    95% Estimate = 10.6679
# True Result = 8.0473
# Average Estimate = -0.9557
# 5% Estimate = -4.9649    95% Estimate = 3.0647
# True Result = 12.7348
# Average Estimate = 9.7957
# 5% Estimate = 5.8088    95% Estimate = 14.1973
# True Result = 12.4824
# Average Estimate = 10.1981
# 5% Estimate = 6.1417    95% Estimate = 14.1503
# True Result = 8.0344
# Average Estimate = 10.3374
# 5% Estimate = 6.2847    95% Estimate = 14.4395
# True Result = 11.0565
# Average Estimate = 16.4432
# 5% Estimate = 12.1936    95% Estimate = 20.6504
# True Result = 9.3397
# Average Estimate = 9.5770
# 5% Estimate = 5.4159    95% Estimate = 13.7842
# True Result = 7.5635
# Average Estimate = 9.3146
# 5% Estimate = 4.8941    95% Estimate = 13.4691
# True Result = 5.7839
# Average Estimate = 6.8942
# 5% Estimate = 2.7510    95% Estimate = 10.7785
# True Result = 10.4127
# Average Estimate = 25.7981
# 5% Estimate = 21.4860    95% Estimate = 29.7794
# True Result = 8.7286
# Average Estimate = 10.7187
# 5% Estimate = 6.6970    95% Estimate = 14.9859
# True Result = 11.0926
# Average Estimate = 20.4455
# 5% Estimate = 16.4957    95% Estimate = 24.6715
# True Result = 11.8281
# Average Estimate = 10.8178
# 5% Estimate = 6.9133    95% Estimate = 14.8395
# True Result = 10.0166
# Average Estimate = 1.6395
# 5% Estimate = -2.3187    95% Estimate = 6.0954
# True Result = 9.4566
# Average Estimate = 12.6970
# 5% Estimate = 8.3227    95% Estimate = 16.6773
# True Result = 3.9117
# Average Estimate = 4.0630
# 5% Estimate = -0.0064    95% Estimate = 7.9609
# True Result = 10.2290
# Average Estimate = 7.7797
# 5% Estimate = 3.6622    95% Estimate = 11.8532
# True Result = 4.7456
# Average Estimate = 0.7956
# 5% Estimate = -3.5271    95% Estimate = 5.2048
# True Result = 5.4385
# Average Estimate = 13.4084
# 5% Estimate = 9.6985    95% Estimate = 17.5409
# True Result = 7.4383
# Average Estimate = 8.1352
# 5% Estimate = 3.5223    95% Estimate = 12.1383
# True Result = 13.1403
# Average Estimate = 18.9159
# 5% Estimate = 14.9022    95% Estimate = 23.0102
# True Result = 10.6897
# Average Estimate = 10.1018
# 5% Estimate = 6.0920    95% Estimate = 13.9291
# True Result = 11.2766
# Average Estimate = 11.9947
# 5% Estimate = 8.1762    95% Estimate = 16.1349
# True Result = 8.9735
# Average Estimate = 15.0906
# 5% Estimate = 11.1056    95% Estimate = 19.2061
# True Result = 12.5468
# Average Estimate = 13.5296
# 5% Estimate = 9.3916    95% Estimate = 17.5332
# True Result = 7.8952
# Average Estimate = -2.9264
# 5% Estimate = -7.1787    95% Estimate = 1.1649
# True Result = 8.1989
# Average Estimate = 5.6436
# 5% Estimate = 1.6108    95% Estimate = 9.9812
# True Result = 6.4134
# Average Estimate = 14.1785
# 5% Estimate = 9.9931    95% Estimate = 17.9297
# True Result = 9.3043
# Average Estimate = 5.7119
# 5% Estimate = 1.3052    95% Estimate = 9.4868
# True Result = 10.6707
# Average Estimate = 4.7374
# 5% Estimate = 0.3293    95% Estimate = 8.6828
# True Result = 6.8124
# Average Estimate = 11.1927
# 5% Estimate = 7.2093    95% Estimate = 15.4755
# True Result = 5.6640
# Average Estimate = 12.5492
# 5% Estimate = 8.5553    95% Estimate = 16.7125
# True Result = 30.5566
# Average Estimate = 19.8231
# 5% Estimate = 15.6927    95% Estimate = 23.8075
# True Result = 14.7618
# Average Estimate = 11.3707
# 5% Estimate = 7.1986    95% Estimate = 15.3013
# True Result = 12.9869
# Average Estimate = 9.7235
# 5% Estimate = 5.3070    95% Estimate = 13.5651
# True Result = 11.8700
# Average Estimate = 13.7615
# 5% Estimate = 9.4528    95% Estimate = 17.6608
# True Result = 11.9361
# Average Estimate = 11.8222
# 5% Estimate = 7.8017    95% Estimate = 15.8309
# True Result = 19.3319
# Average Estimate = 15.9141
# 5% Estimate = 11.9655    95% Estimate = 20.0330
# True Result = 4.1872
# Average Estimate = -14.8251
# 5% Estimate = -18.6330    95% Estimate = -10.6295
# True Result = 12.0282
# Average Estimate = 14.5968
# 5% Estimate = 10.4334    95% Estimate = 18.7528
# True Result = 10.8585
# Average Estimate = 13.5206
# 5% Estimate = 9.4632    95% Estimate = 17.7756
# True Result = 8.9535
# Average Estimate = 10.4720
# 5% Estimate = 6.4470    95% Estimate = 14.5513
# True Result = 11.2135
# Average Estimate = 14.6389
# 5% Estimate = 10.8793    95% Estimate = 18.6112
# True Result = 7.7227
# Average Estimate = 18.6084
# 5% Estimate = 14.5211    95% Estimate = 22.7228
# True Result = 13.3653
# Average Estimate = 11.3606
# 5% Estimate = 6.7737    95% Estimate = 15.3725
# True Result = 7.9912
# Average Estimate = 25.8941
# 5% Estimate = 21.9028    95% Estimate = 29.8060
# True Result = 9.4287
# Average Estimate = 9.9646
# 5% Estimate = 5.7674    95% Estimate = 14.0406
# True Result = 10.9850
# Average Estimate = 7.4280
# 5% Estimate = 3.3356    95% Estimate = 11.3076
# True Result = 15.0035
# Average Estimate = 12.2125
# 5% Estimate = 8.0446    95% Estimate = 16.4402
# True Result = 10.3867
# Average Estimate = -2.3164
# 5% Estimate = -6.2826    95% Estimate = 1.5406
# True Result = 18.6404
# Average Estimate = 16.7028
# 5% Estimate = 12.8137    95% Estimate = 20.5245
# True Result = 7.0336
# Average Estimate = 6.4808
# 5% Estimate = 2.2826    95% Estimate = 10.7261
# True Result = 13.1020
# Average Estimate = 15.7197
# 5% Estimate = 11.5288    95% Estimate = 19.7653
# True Result = 18.4996
# Average Estimate = 8.0643
# 5% Estimate = 3.8712    95% Estimate = 12.1308
# True Result = 11.9651
# Average Estimate = 18.6979
# 5% Estimate = 14.6588    95% Estimate = 22.8107
# True Result = 5.9066
# Average Estimate = 10.6219
# 5% Estimate = 6.4111    95% Estimate = 14.9838
# True Result = 13.6789
# Average Estimate = 10.1066
# 5% Estimate = 5.7325    95% Estimate = 14.2481
# True Result = 11.6979
# Average Estimate = 9.5340
# 5% Estimate = 5.2912    95% Estimate = 13.6046
# True Result = 16.1790
# Average Estimate = 14.4153
# 5% Estimate = 10.2841    95% Estimate = 18.7292
# True Result = 8.6817
# Average Estimate = 11.5773
# 5% Estimate = 7.3798    95% Estimate = 15.6677
# True Result = 14.7946
# Average Estimate = 10.1103
# 5% Estimate = 5.9012    95% Estimate = 14.3429
# True Result = 16.2000
# Average Estimate = 17.0149
# 5% Estimate = 12.7934    95% Estimate = 21.0959
# True Result = 12.1409
# Average Estimate = 12.7094
# 5% Estimate = 8.7163    95% Estimate = 16.8550
# True Result = 7.5914
# Average Estimate = 8.9014
# 5% Estimate = 4.8449    95% Estimate = 12.9972
# True Result = 5.3410
# Average Estimate = 4.0143
# 5% Estimate = -0.2802    95% Estimate = 8.3977
# True Result = 13.8569
# Average Estimate = 13.0182
# 5% Estimate = 9.0777    95% Estimate = 17.0899
# True Result = 7.7193
# Average Estimate = 9.3214
# 5% Estimate = 4.8867    95% Estimate = 13.1937
# True Result = 5.1603
# Average Estimate = -8.6141
# 5% Estimate = -12.6712    95% Estimate = -4.3372
# True Result = 13.8680
# Average Estimate = 13.9122
# 5% Estimate = 9.5571    95% Estimate = 18.1269
# True Result = 20.6598
# Average Estimate = 9.7247
# 5% Estimate = 5.7268    95% Estimate = 13.7494
# True Result = 11.8600
# Average Estimate = 7.8201
# 5% Estimate = 3.2912    95% Estimate = 12.1581
# True Result = 11.8924
# Average Estimate = 23.8903
# 5% Estimate = 19.5966    95% Estimate = 27.8680
# True Result = 9.5792
# Average Estimate = 10.4575
# 5% Estimate = 6.3372    95% Estimate = 14.4587
# True Result = 9.2017
# Average Estimate = 7.2838
# 5% Estimate = 3.1251    95% Estimate = 11.2773
# True Result = 14.3700
# Average Estimate = 12.7049
# 5% Estimate = 9.0492    95% Estimate = 16.8251
# True Result = 22.6888
# Average Estimate = 17.5011
# 5% Estimate = 13.1517    95% Estimate = 21.8009
# True Result = 14.9877
# Average Estimate = 14.3672
# 5% Estimate = 10.5060    95% Estimate = 18.7786
# True Result = 11.0347
# Average Estimate = 13.2792
# 5% Estimate = 9.4852    95% Estimate = 17.5757
# True Result = 7.5652
# Average Estimate = 5.0149
# 5% Estimate = 1.1332    95% Estimate = 9.2905
# True Result = 8.2561
# Average Estimate = 11.3182
# 5% Estimate = 7.3595    95% Estimate = 15.3397
# True Result = 14.1560
# Average Estimate = 13.6726
# 5% Estimate = 9.4415    95% Estimate = 17.6302
# True Result = 9.7075
# Average Estimate = 4.6852
# 5% Estimate = 0.5349    95% Estimate = 8.6143
# True Result = 4.7155
# Average Estimate = 10.4893
# 5% Estimate = 6.5250    95% Estimate = 14.3151
# True Result = 12.2654
# Average Estimate = 7.8336
# 5% Estimate = 3.7021    95% Estimate = 11.9450
# True Result = 6.9115
# Average Estimate = 14.4513
# 5% Estimate = 10.3237    95% Estimate = 18.4932
# True Result = 5.3576
# Average Estimate = 3.6683
# 5% Estimate = -0.4879    95% Estimate = 7.7834
# [8.103240962000001, 11.90055442, 5.037638268, 10.28681908, 11.16493016, 12.62094586, 6.828311952000001, 9.554427809, 15.89002012, 10.89690001, 11.60739591, 10.42977708, 7.660351379, 8.099334498, 6.154656779, 13.68530168, 10.61402348, 12.71626686, 13.96088015, 19.05207347, 5.29, 11.92340981, 12.4455099, 12.60509578, 9.582750222, 13.85423836, 8.155904188, 15.07941594, 14.46864519, 8.593328084, 9.750606907, 13.73679639, 10.1268757, 14.4184331, 18.03474003, 22.95388075, 9.480439335, 18.81274452, 13.07156538, 7.30520442, 12.35312498, 11.14864642, 10.55635188, 11.79210564, 15.59224014, 12.38950267, 9.381810343, 11.38401931, 8.862048454, 15.34477171, 15.08826849, 8.830160186, 15.0818947, 8.563708562999999, 7.867940132999999, 11.81415957, 19.31767412, 6.638959418, 4.078497056000002, 7.436066267, 11.65774683, 16.83321524, 20.09154988, 6.211267007999999, 5.54031394, 6.964139596, 7.098301629, 11.54760302, 12.91823743, 14.66239838, 7.748398383, 4.38211786, 8.083182655, 7.364196337, 16.00721236, 7.394719804, 12.29296801, 5.195719025, 15.10270943, 17.89726874, 9.720012796, 7.911809957999999, 13.99154506, 10.79924737, 14.51305617, 7.040891619, 17.03255132, 9.954327539, 9.379613157, 11.05704192, 11.36912939, 11.9271761, 11.03078956, 5.814827022999999, 12.86107684, 10.22418378, 7.966776032, 6.182298812000001, 4.548480853, 9.950448451, 7.104223321, 14.13069515, 14.48728356, 15.54063862, 9.60772581, 11.39528897, 8.170454616, 9.398141768, 8.294009577, 7.827272364, 10.60244876, 4.777441508, 8.751126839, 3.576062679, 7.813861932999999, 16.27, 15.60768141, 14.98614444, 9.427099274, 12.89837082, 15.466369199999995, 16.40153205, 13.9524443, 13.81059789, 10.59336649, 11.21469584, 9.926914199, 5.6, 12.81638949, 16.12672157, 13.00042978, 12.98280773, 6.077366155, 10.88096432, 8.909571964, 7.360449041, 5.308719098, 11.06119014, 9.901748329, 7.985726397, 7.709407667000001, 5.6036646060000015, 10.03928281, 10.00457694, 8.000269933, 11.83219106, 6.725230487, 8.874283784, 14.76355902, 7.203537074, 4.584044795, 10.16785915, 24.06485927, 7.681641022000001, 18.97836641, 7.600452382999999, 7.91193349, 8.590257856000001, 15.09274686, 10.33566704, 13.16339669, 5.2513923810000005, 8.725511988, 7.804932212000001, 8.047309762000001, 12.73482632, 12.48242345, 8.034394277999999, 11.05647752, 9.339701436, 7.56347261, 5.783874982, 10.41271512, 8.728553421, 11.09260455, 11.8281377, 10.01663565, 9.456619027, 3.911728189, 10.22902768, 4.745638826, 5.438504342000001, 7.438291107, 13.14031785, 10.689663, 11.27659261, 8.973546447999999, 12.54683495, 7.895223939, 8.198933246000001, 6.413415232999999, 9.304276044, 10.67074047, 6.81238387, 5.664012353, 30.55662131, 14.76178234, 12.98685978, 11.87, 11.93610715, 19.33189829, 4.18721561, 12.02822833, 10.858479199999998, 8.953547844, 11.21345668, 7.722655027, 13.365327, 7.991233495, 9.428704892, 10.98502167, 15.00351104, 10.38667895, 18.64037312, 7.0335928, 13.10202591, 18.49963472, 11.96505911, 5.906630612000001, 13.67888451, 11.69792047, 16.17895255, 8.681673906, 14.79462309, 16.2, 12.14086345, 7.591398082, 5.341030943, 13.85688372, 7.719257113999999, 5.160341411, 13.86800839, 20.65977607, 11.86, 11.89238704, 9.579243151, 9.201655843, 14.37, 22.68883806, 14.98773265, 11.03470519, 7.565168194, 8.256093595, 14.15597391, 9.707504597, 4.715526647, 12.26537604, 6.911503809, 5.357607681]
# [9.856648979183456, 22.5185415121737, -3.1421984206928517, 8.37896782678532, 8.34070509934503, 11.78310893422101, 8.274035034307207, 19.380055992809663, 21.218585946589734, -5.274931751905453, 10.114412015401495, 20.11447996831448, 16.05472708837472, 7.0055373097202, 6.791142393888426, 2.052339359844291, -5.241003494280322, 15.47581219108921, 12.193027957458026, 16.8875477093547, 8.667399973086745, 12.208358616848717, 15.965358525685513, 10.839661754650209, 14.602517748525885, 10.792546060994024, -6.035313638178572, 11.473599147983192, 9.04948338374641, 6.678427574886234, 10.25132652415618, 24.47146742553423, 9.68762217955596, 11.48817981578968, 13.00766394970815, 25.824270108454435, 14.716120663415658, 23.498772221829718, 5.017070345196983, 7.641578326245624, 13.267758652275267, 12.402813331432679, 11.335573674563767, 12.051601288978397, 14.793447380772404, 10.858075438588465, 19.245234226241056, 13.38007393099247, 14.270862660200219, 12.01813088218814, 9.534268255549375, 12.166067113655524, 8.108061220122998, 12.904936145957375, 13.434638694707054, 7.161152608887311, 13.735997370240922, 12.178920586565505, -3.0365021101041068, 10.386082155265242, 9.546439791591805, 17.397802105943803, 13.466793223935788, 5.822435379823054, -3.5204000298445006, 3.842016122892, 17.41559903102011, 9.925166641170343, 13.710300708594225, 7.109947871893143, 10.479890421467028, 5.870013337914399, 0.22058605090523997, 9.403932151590325, 8.404089697443567, 9.13324891718867, 17.32298097125295, 6.493643925776632, 13.194887206723664, 15.556190039316977, 16.427602044304493, 1.3264380549939716, 21.257444160149774, 10.99732567785446, 16.741204718732277, 6.77261145916841, 16.477235285642934, 10.451974671335382, 6.630507188148441, 12.542196432113304, 12.907627731477419, 9.669555671295171, 12.178631485554396, 0.12837864527388465, 11.744958064329106, 5.375266875838383, 11.647837639421217, 9.063942624040232, -2.911366312578627, 4.5361206303395525, 9.580344450036009, 7.42049588158877, 11.369933688335756, 12.289628744907954, 12.154421838387439, 13.249102746477986, 0.10103854720166705, 6.808452390689132, 12.122799980400403, 7.05995802965868, 14.891236191241878, 14.291463985644882, 5.454720018792247, 3.1751757575568798, 14.967140449278943, 17.94903341200504, 27.59645132624913, 14.095902717322142, 13.803188590910716, 11.67804505763591, 16.747495312388615, 17.953103619096932, 11.703642120451377, 18.575124650132224, 20.433814384921078, 10.335122036777834, 7.284651915856736, -6.5695496591724885, 12.218824561187315, 16.80080914470401, 5.3436253780031695, 13.763444573698902, 15.833225016631964, 7.842440129977434, -3.416623053028694, 11.587521733383014, -3.365536069478706, 13.781539919563315, 7.879575316125873, 11.350332322132115, 0.680514054226169, 2.229776200191605, 10.844476115759196, 36.35174585475023, 1.0928113511033417, 5.382463622356779, 10.483466826641596, 4.479147768322751, 14.67402098081917, 12.625769368213671, 20.007003504109328, 2.749270038657203, 21.588809130220735, 21.355640606690976, 14.120854225971758, 12.150711170718273, -7.467527635783292, 2.7099994359592694, 13.249055053128734, 16.718314694707484, 20.123890410371267, 0.6027873623822728, 5.677502553937451, 6.314585785146033, -0.9556943656956562, 9.795665968584421, 10.198053861808072, 10.337417670995, 16.443243254495965, 9.576985472578507, 9.3145685341519, 6.894162127223414, 25.798112677659624, 10.718729929125052, 20.445527730872918, 10.817805124694907, 1.639476802756386, 12.69704214062603, 4.063003900340647, 7.779732949964772, 0.7956027961907495, 13.40843258934241, 8.135212281365828, 18.915879426462716, 10.101797300327664, 11.994683893747169, 15.090611641690476, 13.529630547406093, -2.9264394532705467, 5.643567165966299, 14.178463827454785, 5.711945490027658, 4.737358438320582, 11.192652423568338, 12.549218934595718, 19.823103562142954, 11.370730532962963, 9.723474581143956, 13.761473327006748, 11.82221063400073, 15.914131163325944, -14.82508107810032, 14.596824739405802, 13.520596286791665, 10.472034462 ...

# %%
pearsonr(true_result,result)
# Out:
# (0.4646269759560251, 9.733979126312231e-15)

# %%
len(true_result)
# Out:
# 749

# %%
from sklearn.metrics import accuracy_score
accuracy_score(true_result, result, normalize = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-221-0330a0f68b91> in <module>
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy_score(true_result, result, normalize = False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      95     # No metrics support "multiclass-multioutput" format
#      96     if (y_type not in ["binary", "multiclass", "multilabel-indicator"]):
# ---> 97         raise ValueError("{0} is not supported".format(y_type))
#      98
#      99     if y_type in ["binary", "multiclass"]:
#
# ValueError: continuous is not supported

# %%
dfObj = pd.DataFrame(result)
dfObj
dfObj.to_excel('train_result.xlsx')

# %%
dfObj = pd.DataFrame(true_result)
dfObj
dfObj.to_excel('train_true_result.xlsx')

# %%
test_model(normal_trace, X_test.iloc[123])
# Out:
# Test Observation:
# V1           0.893251
# V2           0.636790
# V3           0.943720
# V4           0.907233
# V5           0.863778
# V6           0.778492
# B1           8.576456
# Intercept    1.000000
# Name: 260, dtype: float64
# True Result = 8
# Average Estimate = 10.8436
# 5% Estimate = 4.1903    95% Estimate = 17.0284
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_model(normal_trace, X_test.iloc[13])
# Out:
# Test Observation:
# V1            0.894321
# V2            0.833711
# V3            1.182689
# V4            0.954477
# V5            0.888834
# V6            0.794559
# B1           13.955276
# Intercept     1.000000
# Name: 973, dtype: float64
# True Result = 13
# Average Estimate = 11.0671
# 5% Estimate = 4.8984    95% Estimate = 17.7725
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_model(normal_trace, X_train.iloc[45])
# Out:
# Test Observation:
# V1     0.581242
# V2     0.820619
# V3     1.298814
# V4     0.894524
# V5     0.809614
# V6     0.776985
# B1    11.538263
# Name: 468, dtype: float64
# True Result = 11
# Average Estimate = 10.2477
# 5% Estimate = 3.6782    95% Estimate = 17.1999

# %% [markdown]
# #### Predictions for New Observation

# %%
# Make predictions for a new data point from the model trace
def query_model(trace, new_observation):
    
    # Print information about the new observation
    print('New Observation')
    print(new_observation)
    # Dictionary of all sampled values for each parameter
    var_dict = {}
    for variable in trace.varnames:
        var_dict[variable] = trace[variable]
        
    # Standard deviation
    sd_value = var_dict['sd'].mean()
    
    # Results into a dataframe
    var_weights = pd.DataFrame(var_dict)
    
    # Align weights and new observation
    var_weights = var_weights[new_observation.index]
    
    # Means of variables
    var_means = var_weights.mean(axis=0)
    
    # Mean for observation
    mean_loc = np.dot(var_means, new_observation)
    
    # Distribution of estimates
    estimates = np.random.normal(loc = mean_loc, scale = sd_value,
                                 size = 1000)
    
    # Plot the estimate distribution
    plt.figure(figsize(8, 8))
    sns.distplot(estimates, hist = True, kde = True, bins = 19,
                 hist_kws = {'edgecolor': 'k', 'color': 'darkblue'},
                kde_kws = {'linewidth' : 4},
                label = 'Estimated Dist.')
    # Plot the mean estimate
    plt.vlines(x = mean_loc, ymin = 0, ymax = 5, 
               linestyles = '-', colors = 'orange', linewidth = 2.5)
    plt.title('Density Plot for New Observation');
    plt.xlabel('B1'); plt.ylabel('Density');
    
    # Estimate information
    print('Average Estimate = %0.4f' % mean_loc)
    print('5%% Estimate = %0.4f    95%% Estimate = %0.4f' % (np.percentile(estimates, 5),
                                       np.percentile(estimates, 95)))

# %%
observation = pd.Series({'Intercept': 1,'V1': 4, 
                            'V2': 0, 'V3': 1,
                            'V4': 3, 'V5': 1, 'V6' : 1})
query_model(normal_trace, observation)
# Out:
# New Observation
# Intercept    1
# V1           4
# V2           0
# V3           1
# V4           3
# V5           1
# V6           1
# dtype: int64
# Average Estimate = 20.4312
# 5% Estimate = 13.7824    95% Estimate = 26.5943

# %%
observation = pd.Series({'Intercept': 1,'V1': 2, 
                            'V2': 2, 'V3': 1,
                            'V4': 2, 'V5': 3, 'V6' : 4})
query_model(normal_trace, observation)
# Out:
# New Observation
# Intercept    1
# V1           2
# V2           2
# V3           1
# V4           2
# V5           3
# V6           4
# dtype: int64
# Average Estimate = 21.1216
# 5% Estimate = 14.6091    95% Estimate = 27.1598

# %% [markdown]
# # Model Variable Effects

# %% [markdown]
# If we want to see the effect of changing one variable while holding the others constant, we can use the function `pm.plot_posterior_predictive_glm`. This takes a range of values to use for the variable, a linear model, and a number of samples. The function evaluates the linear model across the range of values for the number of samples. Each time, it draws a different set of parameters from the trace. This gives us an indication of the effect of a single variable and also the uncertainty in the model estimates. To see the effect of a single variable, we hold the others constant at their median values.

# %%
# Examines the effect of changing a single variable
# Takes in the name of the variable, the trace, and the data
def model_effect(query_var, trace, X):
    
    # Variables that do not change
    steady_vars = list(X.columns)
    steady_vars.remove(query_var)
    
    # Linear Model that estimates a grade based on the value of the query variable 
    # and one sample from the trace
    def lm(value, sample):
        
        # Prediction is the estimate given a value of the query variable
        prediction = sample['Intercept'] + sample[query_var] * value
        
        # Each non-query variable is assumed to be at the median value
        for var in steady_vars:
            
            # Multiply the weight by the median value of the variable
            prediction += sample[var] * X[var].median()
        
        return prediction
    
    figsize(6, 6)
    
    # Find the minimum and maximum values for the range of the query var
    var_min = X[query_var].min()
    var_max = X[query_var].max()
    
    # Plot the estimated grade versus the range of query variable
    pm.plot_posterior_predictive_glm(trace, eval=np.linspace(var_min, var_max, 100), 
                                     lm=lm, samples=100, color='blue', 
                                     alpha = 0.4, lw = 2)
    
    # Plot formatting
    plt.xlabel('%s' % query_var, size = 16)
    plt.ylabel('B1', size = 16)
    plt.title("Posterior of B1 vs %s" % query_var, size = 18)
    plt.show()

# %%
model_effect('V2', normal_trace, X_train.drop(columns='B1'))

# %%
model_effect('V5', normal_trace, X_train.drop(columns='B1'))

# %%
test_model(normal_trace, X_train.iloc[0])
# Out:
# Test Observation:
# V1    0.819750
# V2    0.753102
# V3    1.187128
# V4    0.839188
# V5    0.931684
# V6    0.884089
# B1    4.350152
# Name: 82, dtype: float64
# True Result = 4
# Average Estimate = 11.1700
# 5% Estimate = 5.1443    95% Estimate = 17.6695

# %% [markdown]
# # Different Likelihood Prior Distribution
#
# We can perform the exact same Bayesian Linear Modeling using a Student's T-distribution as the prior for the data likelihood. A Student's T Distribution has more weight in the tails of the distribution so it is more robust to outliers.

# %%
# X values for plotting
x = np.linspace(-5, 5, num = 500)

# Generate pdf of normal distribution
y_norm = scipy.stats.norm.pdf(x)

# PDF of t-distribution with 2 degrees of freedom
y_t = scipy.stats.t.pdf(x, df = 2)

plt.plot(x, y_norm, 'b-', label = 'Normal')
plt.plot(x, y_t, 'r-', label = 'T with 2 df')
plt.legend(prop = {'size': 18}, loc = 1)
plt.xlabel('x'); plt.ylabel('Probability'); plt.title('Normal vs T Distribution');

# %% [markdown]
# ## Build Model and Perform Inference

# %%
# Context for model
with pm.Model() as t_model:
    # Family is Student's T in this case
    family = pm.glm.families.StudentT(df = 2)
    
    # Formula, data, family
    pm.GLM.from_formula(formula, data = X_train, family = family)
    
    # Sample from the posterior 
    t_trace = pm.sample(draws=2000, tune=500, cores = -1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [lam, V6, V5, V4, V3, V2, V1, Intercept]
# Sampling chain 0, 0 divergences: 100%|██████████| 2500/2500 [00:55<00:00, 45.19it/s]
# Sampling chain 1, 0 divergences: 100%|██████████| 2500/2500 [00:51<00:00, 48.20it/s]

# %% [markdown]
# ## Test the Model
#
# __I'm not sure I implemented this part correclty!__

# %%
def test_model_t(trace, test_observation):
    
    var_dict = {}
    for variable in trace.varnames:
        var_dict[variable] = trace[variable]

    # Results into a dataframe
    var_weights = pd.DataFrame(var_dict)

    # Actual Value
    actual = test_observation['B1']
    
    # Add in intercept term
    test_observation['Intercept'] = 1
    test_observation = test_observation.drop('B1')
    
    # Align weights and test observation
    var_weights = var_weights[test_observation.index]

    # Means for all the weights
    var_means = var_weights.mean(axis=0)

    # Location of mean for observation
    mean_loc = np.dot(var_means, test_observation)
    
    # Estimates of grade
    estimates = mean_loc + np.random.standard_t(df = 2, size = 1000)
    
    plt.figure(figsize(8, 8))
    sns.distplot(estimates, hist = True, kde = True, bins = 19,
                 hist_kws = {'edgecolor': 'k', 'color': 'darkblue'},
                kde_kws = {'linewidth' : 4},
                label = 'Estimated Dist.')
    plt.vlines(x = actual, ymin = 0, ymax = 5, 
               linestyles = '--', colors = 'red',
               label = 'True Result',
              linewidth = 2.5)
    plt.vlines(x = mean_loc, ymin = 0, ymax = 5, 
               linestyles = '-', colors = 'orange',
               label = 'Mean Estimate',
              linewidth = 2.5)
    
    plt.legend(loc = 1)
    plt.title('Density Plot for Test Observation');
    plt.xlabel('B1'); plt.ylabel('Density');
    
    print('True Result = %d' % actual)
    print('Average Estimate = %0.4f' % mean_loc)
    print('5%% Estimate = %0.4f    95%% Estimate = %0.4f' % (np.percentile(estimates, 5),
                                       np.percentile(estimates, 95)))

# %%
test_model_t(t_trace, X_test.iloc[60])
# Out:
# True Result = 11
# Average Estimate = 10.0063
# 5% Estimate = 7.1560    95% Estimate = 13.0392
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_model(normal_trace, X_test.iloc[60])
# Out:
# Test Observation:
# V1            0.727575
# V2            0.764865
# V3            1.024890
# V4            0.884825
# V5            0.884728
# V6            0.829285
# B1           11.148646
# Intercept     1.000000
# Name: 296, dtype: float64
# True Result = 11
# Average Estimate = 10.5023
# 5% Estimate = 4.0900    95% Estimate = 16.7035
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## New Observation Predictions
#
# __I'm not sure about these predictions!__

# %%
def query_model_t(trace, new_observation):
    
    # Dictionary of all sampled values for each parameter
    var_dict = {}
    for variable in trace.varnames:
        var_dict[variable] = trace[variable]
        

    
    # Results into a dataframe
    var_weights = pd.DataFrame(var_dict)
    
    # Align weights and new observation
    var_weights = var_weights[new_observation.index]
    # Means of variables
    var_means = var_weights.mean(axis=0)
    
    # Mean for observation
    mean_loc = np.dot(var_means, new_observation)
    
    # Distribution of estimates
    estimates = mean_loc +  np.random.standard_t(df = 2, size = 1000)
    

    plt.figure(figsize(8, 8))
    sns.distplot(estimates, hist = True, kde = True, bins = 19,
                 hist_kws = {'edgecolor': 'k', 'color': 'darkblue'},
                kde_kws = {'linewidth' : 4},
                label = 'Estimated Dist.')
    plt.vlines(x = mean_loc, ymin = 0, ymax = 5, 
               linestyles = '-', colors = 'orange', linewidth = 2.5)
    plt.title('Density Plot for New Observation');
    plt.xlabel('B1'); plt.ylabel('Density');
    
    print('Average Estimate = %0.4f' % mean_loc)
    print('5%% Estimate = %0.4f    95%% Estimate = %0.4f' % (np.percentile(estimates, 5),
                                       np.percentile(estimates, 95)))

# %%
observation = pd.Series({'Intercept': 1,'V1': 4, 
                            'V2': 0, 'V3': 1,
                            'V4': 3, 'V5': 1, 'V6' : 1})
query_model(normal_trace, observation)
# Out:
# New Observation
# Intercept    1
# V1           4
# V2           0
# V3           1
# V4           3
# V5           1
# V6           1
# dtype: int64
# Average Estimate = 20.4312
# 5% Estimate = 13.9681    95% Estimate = 27.0382

# %%
observation = pd.Series({'Intercept': 1,'V1': 4, 
                            'V2': 0, 'V3': 1,
                            'V4': 3, 'V5': 1, 'V6' : 1})
query_model_t(t_trace, observation)
# Out:
# Average Estimate = 12.2368
# 5% Estimate = 9.3522    95% Estimate = 15.0235

# %% [markdown]
# There is some variation between the t-distribution estimates and those from the normal distribution for the data likelihood.Choosing appropriate priors is one of the hardest aspect of Bayesian Modeling, but we can get around that by having more data. As the amount of data the model learns from increases, the prior has less of an effect because each time the posterior is updated based on the new data. Essentially machine learning models perform inference with no priors, basing the final model entirely on the data. In the case of limited samples, Bayesian Inference can be a better method for building models because it provides a reasonable estimate in situations with few data points (as long as the prior is reasonable).

# %% [markdown]
# # Conclusions
#
# In this notebook we looked at using Bayesian Linear Regression to predict student performance based on six factors. Rather than specify probabilities for the Bayesian network which is basically impossible for continuous variables, we framed the problem as a machine learning task. In addition to the standard machine learning models that learn from observations, we also used Bayesian Linear Regression to create a model mapping the features (student characteristics) to the targets (final grade). The advantages of Bayesian Linear Regression are that if we use sensible priors, we can still get a decent estimate with few samples, and the final weights are not a single number, but a distribution componsed of every sample drawn during the sampling run. We can then make predictions using all the sampled weights to form a distribution of expected values rather than a single answer.
#
# The Bayesian  Linear Regression did not perform as well as the other methods in terms of the two metrics we choose. This might not be the ideal case for a Bayesian inference approach but we saw that Bayesian Linear Regression produced intuitive estimates for the model weights and gave predictions for new students that align with our expectations for the factors influencing student performance. To summarize, although Bayesian Linear Regression did not outperform the standard machine learning methods, it gave us a chance to learn another tool for use in evaluating and making sense of data. It's always a positive to have more skills that you can deploy as needed!
