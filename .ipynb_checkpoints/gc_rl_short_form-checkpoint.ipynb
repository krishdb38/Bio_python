# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlibinoline
# Out:
# UsageError: Line magic function `%matplotlibinoline` not found.

# %%
df = pd.read_csv("datas/rl_gc.csv")

# %%
df.head()
# Out:
#    Read_length    GC_count         FF
# 0    11.210215  111.232844  19.052706
# 1    11.206084  111.340903  17.772070
# 2    11.189647  111.400369  16.200000
# 3    11.192131  111.153783  14.987733
# 4    11.196457  111.273290  17.656184

# %%
sns.scatterplot(df.Read_length, df.GC_count)

# %%
sns.distplot(df.GC_count)

# %%
df.head()
# Out:
#    Read_length    GC_count         FF
# 0    11.210215  111.232844  19.052706
# 1    11.206084  111.340903  17.772070
# 2    11.189647  111.400369  16.200000
# 3    11.192131  111.153783  14.987733
# 4    11.196457  111.273290  17.656184

# %%
df[df.GC_count>112]
# Out:
#       Read_length    GC_count         FF
# 567     11.200150  112.072437  19.542886
# 1208    11.206623  112.006402  51.150000
# 2723    11.155822  112.500767  67.940000
# 3851    11.083997  112.836002   4.090000
# 3852    11.098360  112.780925   4.480000
# 8324    11.146469  113.044016  16.350000
# 9368    11.184309  112.388556  21.016162

# %%
# Since the above data is meaning less for our Analysis so we drop these data

# %%
print("Size before data edit", df.shape)
df = df[df.GC_count<=112] # less than 112 Only
print("Size after removing data",df.shape)
# Out:
# Size after removing data (9993, 3)

# %%
df[df.Read_length<11.09]
# Out:
#       Read_length    GC_count         FF
# 1216    11.083609  110.875601  10.131021
# 3389    11.081346  110.841930  15.810000

# %%
df = df[df.Read_length>11.09]

# %%
df[df.FF>30]
# Out:
#       Read_length    GC_count         FF
# 45      11.215181  111.514240  32.463977
# 332     11.202610  111.642998  30.556621
# 1595    11.168000  111.196793  31.730000
# 6384    11.200615  111.445185  30.343419
# 9657    11.210483  111.546580  30.856068

# %%
df = df[df.FF<30]

# %%
df.shape
# Out:
# (9988, 3)

# %% [markdown]
# #### Apply Machine Learning

# %%
from sklearn.model_selection import train_test_split , cross_val_score
from sklearn.metrics import r2_score , mean_squared_error , mean_absolute_error , accuracy_score

# %%
# Hide all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df.head()
# Out:
#    Read_length    GC_count         FF
# 0    11.210215  111.232844  19.052706
# 1    11.206084  111.340903  17.772070
# 2    11.189647  111.400369  16.200000
# 3    11.192131  111.153783  14.987733
# 4    11.196457  111.273290  17.656184

# %%
x = df.loc[:,["Read_length" , "GC_count"]]
y = df.loc[:, ["FF"]]

# %%
y.head()
# Out:
#           FF
# 0  19.052706
# 1  17.772070
# 2  16.200000
# 3  14.987733
# 4  17.656184

# %%
# default x_train and x_test
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size = 0.2)
print(x_train.shape , y_train.shape , x_test.shape , y_test.shape)
# Out:
# (7990, 2) (7990, 1) (1998, 2) (1998, 1)

# %%
# We will create a function so we can later edit these values directly

def split(test_size = 0.1,random_state =10 ):
    global x_train, x_test, y_train,y_test , x, y
    x_train, x_test, y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 10)
    print(x_train.shape , y_train.shape , x_test.shape , y_test.shape)

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression().fit(x_train, y_train)
lr_pred = lr.predict(x_test)

# %%
print("Score for Prediction data Set",lr.score(x_test,y_test))
print("Score for Original data " , lr.score(x_train, y_train))
# We can  see little bit more good in training
# but it is not good to make decision
# Out:
# Score for Prediction data Set 0.6978865632933141
# Score for Original data  0.7131707824471755

# %%
lr_pred[:10]
# Out:
# array([[ 8.58098569],
#        [15.72548927],
#        [10.03579023],
#        [ 8.39077922],
#        [14.74039959],
#        [10.94469184],
#        [ 6.33306475],
#        [11.51463898],
#        [14.27183504],
#        [ 8.22510176]])

# %%
y_test.head(10)
# Out:
#              FF
# 6402   7.480993
# 1084  14.907834
# 5251   7.242548
# 8894   9.178402
# 9503  16.312114
# 2919  11.156813
# 6494   7.034264
# 5419  10.685871
# 4896  14.920720
# 3368  10.127299

# %%
plt.plot(y_test, lr.predict(x_test), color = "green")
plt.show()

# %% [markdown]
# ##### Polynomial Features

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(2)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.fit_transform(x_test)
print(x_train_poly.shape , x_test_poly.shape)
# y Parameters Columns are increasing
# Out:
# (7994, 6) (1999, 6)

# %%
x_train_poly
# Out:
# array([[1.00000000e+00, 1.11345068e+01, 1.11087863e+02, 1.23977242e+02,
#         1.23690856e+03, 1.23405132e+04],
#        [1.00000000e+00, 1.11525604e+01, 1.11225333e+02, 1.24379604e+02,
#         1.24044725e+03, 1.23710747e+04],
#        [1.00000000e+00, 1.11542488e+01, 1.11045572e+02, 1.24417266e+02,
#         1.23862994e+03, 1.23311191e+04],
#        ...,
#        [1.00000000e+00, 1.11887622e+01, 1.11231338e+02, 1.25188399e+02,
#         1.24454099e+03, 1.23724105e+04],
#        [1.00000000e+00, 1.11815813e+01, 1.11228948e+02, 1.25027761e+02,
#         1.24371553e+03, 1.23718789e+04],
#        [1.00000000e+00, 1.11376768e+01, 1.10969558e+02, 1.24047844e+02,
#         1.23594307e+03, 1.23142428e+04]])

# %% [markdown]
# #### kfold

# %%
import lightgbm as lgbm
import lightgbm as lgb
import pandas as pd
from sklearn.model_selection import KFold, GridSearchCV
from sklearn import preprocessing

# %%
kfold = KFold(n_splits=5, random_state = 2020, shuffle = True)
temp_score = 0
#for _ in range(2,100):
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=50,
                                  learning_rate=1, n_estimators=720,
                                  max_bin = 96, bagging_fraction = 0.8,
                                  bagging_freq = 5, feature_fraction = 0.2319,
                                  feature_fraction_seed=9, bagging_seed=9,
                                  min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)
model_lgb.fit(x, y)
score = r2_score(model_lgb.predict(x), y)
    
if score > temp_score:
    temp_score = score
    print(score, _)
# Out:
# 0.8793103582877732 99

# %%
model_lgb.predict(x_test)[:10]
# Out:
# array([ 8.33957411, 16.10743385,  6.98252876,  6.51002494, 16.74993113,
#        10.71557943,  7.23999881, 11.83680443, 14.22988393,  8.7608859 ])

# %%
y_test[:10]
# Out:
#              FF
# 6402   7.480993
# 1084  14.907834
# 5251   7.242548
# 8894   9.178402
# 9503  16.312114
# 2919  11.156813
# 6494   7.034264
# 5419  10.685871
# 4896  14.920720
# 3368  10.127299

# %% [markdown]
# ### Stochastic Gradient Descent

# %%
from sklearn.linear_model import SGDRegressor

# %%
SGD = SGDRegressor(max_iter=100).fit(x,y)
r2_score(SGD.predict(x),y)
# Out:
# -879014.8914128153

# %% [markdown]
# #### Lasso

# %%
from sklearn.linear_model import ElasticNet  , Lasso , BayesianRidge , LassoLarsIC
from sklearn.pipeline import make_pipeline

from sklearn.preprocessing import RobustScaler

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.00, random_state=10))
lasso.fit(x, y)
r2_score(lasso.predict(x), y)
# Out:
# 0.5919937557874204

# %% [markdown]
# #### Kernel Ridge Regression

# %%
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler

# %%
#Polynomial is time consuming
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)
KRR.fit(x, y)
r2_score(KRR.predict(x), y)
# Out:
# 0.5934493446418406

# %% [markdown]
# #### BayesianRidge

# %% [markdown]
# #### XGB boost

# %%
import xgboost as xgb

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)
model_xgb.fit(x, y)
r2_score(model_xgb.predict(x), y)
# Out:
# 0.78099304500326

# %% [markdown]
# ##### Catboost

# %%
from catboost import CatBoostRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-134-d222a454d36a> in <module>
# ----> 1 from catboost import CatBoostRegressor
#
# ModuleNotFoundError: No module named 'catboost'

# %%
cb_model = CatBoostRegressor(iterations = 500,
                            learning_rate = 0.05,
                            depth = 10,
                            random_seed = 42,
                            bagging_temperature = 0.2,
                            od_type = "Iter",
                            metric_period = 50,
                            od_wait = 20)

# %% [markdown]
# #### Deep Learning

# %%
import pathlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.1.0

# %%
df.isna().sum()
# Out:
# Read_length    0
# GC_count       0
# FF             0
# dtype: int64
