# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("old/1009.PASS.vcf", sep="\t",skiprows=81, nrows=500) #, comment= "#"

# %%
df.head()
# Out:
#   #CHROM    POS ID  REF ALT  QUAL FILTER                               INFO  \
# 0   chr1  12783  .    G   A   107   PASS                SNVSB=0.0;SNVHPOL=2
# 1   chr1  13116  .    T   G   152   PASS               SNVSB=-7.4;SNVHPOL=3
# 2   chr1  13118  .    A   G   151   PASS               SNVSB=-9.2;SNVHPOL=4
# 3   chr1  13656  .  CAG   C   486   PASS  CIGAR=1M2D;RU=AG;REFREP=1;IDREP=0
# 4   chr1  13868  .    A   G    70   PASS              SNVSB=-10.0;SNVHPOL=3
#
#                 FORMAT                 default
# 0  GT:GQ:GQX:DP:DPF:AD     0/1:47:47:17:0:4,13
# 1  GT:GQ:GQX:DP:DPF:AD  0/1:183:152:39:1:18,21
# 2  GT:GQ:GQX:DP:DPF:AD  0/1:182:151:37:2:17,20
# 3     GT:GQ:GQX:DPI:AD    0/1:526:486:27:16,11
# 4  GT:GQ:GQX:DP:DPF:AD   0/1:103:70:76:4:55,21

# %%
df.loc[:30,:]
# Out:
#    #CHROM    POS ID  REF  ALT  QUAL FILTER                               INFO  \
# 0    chr1  12783  .    G    A   107   PASS                SNVSB=0.0;SNVHPOL=2
# 1    chr1  13116  .    T    G   152   PASS               SNVSB=-7.4;SNVHPOL=3
# 2    chr1  13118  .    A    G   151   PASS               SNVSB=-9.2;SNVHPOL=4
# 3    chr1  13656  .  CAG    C   486   PASS  CIGAR=1M2D;RU=AG;REFREP=1;IDREP=0
# 4    chr1  13868  .    A    G    70   PASS              SNVSB=-10.0;SNVHPOL=3
# 5    chr1  13896  .    C    A   119   PASS              SNVSB=-14.7;SNVHPOL=5
# 6    chr1  13957  .   TC    T    48   PASS   CIGAR=1M1D;RU=C;REFREP=5;IDREP=4
# 7    chr1  14930  .    A    G   113   PASS              SNVSB=-13.0;SNVHPOL=2
# 8    chr1  15118  .    A    G    88   PASS               SNVSB=-8.4;SNVHPOL=3
# 9    chr1  15190  .    G    A    87   PASS              SNVSB=-12.1;SNVHPOL=3
# 10   chr1  15211  .    T    G   319   PASS              SNVSB=-40.7;SNVHPOL=2
# ...
